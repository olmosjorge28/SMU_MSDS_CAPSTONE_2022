# %%
# standard libraries
import pandas as pd
import numpy as np
import os
from IPython.display import Image
#from IPython.display import clear_output
import time
#import re

# visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from tabulate import tabulate
import altair as alt
alt.data_transformers.disable_max_rows()
# Out:
# DataTransformerRegistry.enable('default')

# %%
import json

# %%
f = open('atomichub.config')
data = json.load(f)

# %%
data.get('data').get('global').get('col.blist')
# Out:
# ['waxforerotic',
#  'garbagepailz',
#  'streetfighte',
#  'metalslugnft',
#  'pokemon12345',
#  'varievarie12',
#  'caricaturexx',
#  'monalisanft1',
#  'jesusnft1234',
#  'wwaxxxbabess',
#  'safexnft5555',
#  'realelection',
#  'election2o2o',
#  'jipewrgvpiwp',
#  'kogsfail1234',
#  'mariounivers',
#  'crshgrdnmeme',
#  'coingeniusxv',
#  'nftdayallday',
#  'craslhgordon',
#  'duelingchain',
#  'officialcsgo',
#  'darkdarkdark',
#  'o1o1o1o1o1o1',
#  'coolasset123',
#  'pepeheroesio',
#  'pepeheroesii',
#  'pepeheroesgo',
#  'pepelovesall',
#  'darkcountruh',
#  'darkcuontryh',
#  'kembosaakgif',
#  'chibisgoobal',
#  '1jcjxbr5d3aj',
#  'emofaceart11',
#  'unlimitedwax',
#  'kogsoficial1',
#  'paintingart3',
#  'shatnertweet',
#  'exhilaration',
#  'xnxxdotcom11',
#  'cryptokitti1',
#  'thedopenft11',
#  'pokemoncardd',
#  'triballbooks',
#  'mikescollect',
#  'dungeonworld',
#  '12345rainbow',
#  'freefiregame',
#  'tradition212',
#  'nftrashreals',
#  'onchainheroo',
#  'electroman33',
#  'cryptomania1',
#  'cryptmania52',
#  'gundamfans45',
#  'legendary111',
#  'tribalbook11',
#  'satoshinew33',
#  'shamaneye123',
#  'vitaliknft12',
#  'oldmask12121',
#  'zamuraionwax',
#  'dvburkeart11',
#  'creepmachine',
#  'tryadultfunn',
#  'miakhalifaxx',
#  'vinataba1111',
#  'miaoriginsss',
#  'luckeyfish12',
#  'miaoriginall',
#  'alienworldss',
#  'emojiartreal',
#  'cybernosfrt1',
#  'stretfighter',
#  'cardseriess1',
#  'fondmemories',
#  'twerkypepe11',
#  '2pokemenbolg',
#  '1pokemenbolg',
#  'tothemoomsun',
#  'metallicaaaa',
#  'capitalriots',
#  'seven1111111',
#  'faketestbtco',
#  'fridaybhhero',
#  'asedekontoll',
#  'rabbithole11',
#  'dragononfire',
#  'twerkyypepes',
#  'anthon1hurdy',
#  'pixelartsgif',
#  'nightmareart',
#  'aussieartist',
#  'nftastrology',
#  '1mutantninja',
#  'pathofexiles',
#  'creaturanary',
#  'girlsquadart',
#  'waifucollect',
#  'belajaran123',
#  'fillthespace',
#  'gifartonwax1',
#  'mortalworlds',
#  'hasankhalifa',
#  'blockheroess',
#  'hasandasilva',
#  'beautyofntr1',
#  'babyyodalove',
#  'lemurdtooold',
#  'cryptodrugsy',
#  'ssttffcapcom',
#  'capcommarvel',
#  'btcorigins11',
#  'stfcapconnv1',
#  'worldofblock',
#  'thisisatest1',
#  'justloveeeee',
#  'blockchain22',
#  'layerlines42',
#  'tombradycard',
#  'memestonktop',
#  'memestonksss',
#  'epilepticimg',
#  'samuraifight',
#  'cute123anime',
#  'dancingstree',
#  'artepileptic',
#  'blackmoney12',
#  'robonomicaio',
#  'robonomicaof',
#  'fightherenow',
#  'gameskardsmk',
#  'alwayspastel',
#  'bestrockband',
#  'zerotwozeroz',
#  'demonslayerq',
#  'narutoshipud',
#  'dokidokipunk',
#  'emilnazaroff',
#  'bobopixelox2',
#  'twozerotwoze',
#  'ssssdynadyna',
#  'dragonballxx',
#  'olditemworld',
#  'placeitsupzc',
#  'litetigertes',
#  'despairlovez',
#  'seralkillerr',
#  'cinematicnft',
#  'traspailkids',
#  'bakuretsuhun',
#  'legendpeople',
#  'stickergamee',
#  'hollowoodddd',
#  'azanellonfts',
#  'howtomakegri',
#  'beepleorigin',
#  'bravebrowser',
#  'digitalblock',
#  'joinmyshower',
#  'kinky4crypto',
#  'traintagsuno',
#  'bloodbathsix',
#  'vaporwaveart',
#  'ligermanspor',
#  'drawingsglau',
#  'nftfantasy23',
#  'btcartdrops1',
#  'beautywifeee',
#  'sexygirlblow',
#  'dripmon11552',
#  'uplandscards',
#  'uplandccards',
#  'ultrahorrops',
#  'rplanetverif',
#  'upland1cards',
#  'monsterrstr2',
#  'uplivtworld2',
#  'gdztoppsvver',
#  'rplanetverlf',
#  'bitcoinnft21',
#  'alienwoorlds',
#  'bitcoinorijn',
#  'alienlworlds',
#  'aliennworlds',
#  'headzcardz21',
#  'cryptamoonie',
#  'bitcinorignn',
#  'ultrahorross',
#  'bitcoisorign',
#  'ultrahorrore',
#  'ultrahorroro',
#  'ultrahorrorr',
#  'aliencworlds',
#  'alieniworlds',
#  'alienworllds',
#  'alienlworldc',
#  'alienwor1dss',
#  'aliencworldc',
#  'alienworlddd',
#  'alienrarepac',
#  'alienworld15',
#  'alienofworld',
#  'aliensworlds',
#  'alienworldll',
#  'alienworldla',
#  'alienworlds1',
#  'alienswoorld',
#  'flegandsnfts',
#  'a1ienswor1ds',
#  'ultrehorrors',
#  'a1iensworlds',
#  'u1trahorrors',
#  'aiiencworlds',
#  'rplanntverif',
#  'e2tradacards',
#  'cartoombsir2',
#  'aillenworlds',
#  'alieenworlds',
#  'aiienworldss',
#  'ailllenworld',
#  'allonworldes',
#  'sp1lecomdon1',
#  'alienworrlds',
#  'alienworldds',
#  'tribalbookcv',
#  'uplanddcards',
#  'rplanetverff',
#  'ultraahorror',
#  'alllenworlks',
#  'alonworldscs',
#  'allllenworld',
#  'aliensworldc',
#  'alienswrolds',
#  'aliennnworld',
#  'alienwshards',
#  'allenworldss',
#  'alilenworlds',
#  'toolsworldss',
#  'fntfantasyhq',
#  'alienwarlds1',
#  'alleenworlds',
#  'alienvvorlds',
#  'aleinwollrds',
#  'toolswordsds',
#  'elianwordsss',
#  'basicexplosv',
#  'methaneswamp',
#  'ailenwoorlds',
#  'prplanettttt',
#  'aliennwor1ds',
#  'alienworldls',
#  'aliienworlds',
#  'hodlgodveiif',
#  'alienvworlds',
#  'aalienvorlds',
#  'cryptohentai',
#  'belledelphxx',
#  'cryptopornxx',
#  'pornhubcard2',
#  'alienswor1ds',
#  'alienworlids',
#  'a1ienlworlds',
#  'alliemworlds',
#  'aleensworlds',
#  'allensworlds',
#  'allienworlds',
#  'aalienworlds',
#  'bitverseveri',
#  'backsllkiozx',
#  'erzra.wam',
#  'aiienwvorlds',
#  'aiienvvorlds',
#  'alienwworlds',
#  'alienwvorlds',
#  'alienzwor1ds',
#  'alienworldnf',
#  'al1ensworlds',
#  'ailienworlds',
#  'arienworldss',
#  'a1ieneworlds',
#  'a1ienzworlds',
#  'alleniworlds',
#  'allenvvorlds',
#  'alienwordsru',
#  'alienwordseu',
#  'alienvvorld1',
#  'alianeworlds',
#  'allienwor1ds',
#  'alienaworlds',
#  'alienworlbse',
#  'myowntoolsxd',
#  'aleinsworlds',
#  'alliienworld',
#  'a1lienworlds',
#  'alieneworlds',
#  'allenvvorids',
#  'a1iienwor1ds',
#  'a11ienworlds',
#  'a11ianworlds',
#  'alienvvordls',
#  'alionvvorlds',
#  'alienworldzz',
#  'bitconorigin',
#  'bscexplosive',
#  'alieennwords',
#  'leeeeeeeeeel',
#  'basicexplosi',
#  'allienvvorld',
#  'quantumdrill',
#  'aliienswolds',
#  'allienvvolds',
#  'eargeexplose',
#  'rarenft12345',
#  'alienvvor1ds',
#  'bitversevere',
#  'alienswolrds',
#  'a1ienvvorlds',
#  'a1ienvvor1de',
#  'alienvorldss',
#  'a1ienswor1de',
#  'alienworld1f',
#  'alienrworlds',
#  'toolalienwor',
#  'alienworldsi',
#  'alienvvorld3',
#  'aw1alienwrld',
#  'alienworlds4',
#  'alienworlds5',
#  'alienzworlds',
#  'alienworlcls',
#  'alientools13',
#  'alienvvorld2',
#  'alienworlds3',
#  'aliensworldz',
#  'aallienworld',
#  'aiiensworlds',
#  'aliiennworld',
#  'allianworlds',
#  'a1ienlwor1ds',
#  'exitlimbawam',
#  'exit1imbowax',
#  'exitlimbawax',
#  'exitlimbowam',
#  'allienswords',
#  'upliftwor1d2',
#  'rp1anetverif',
#  'exitiimbowax',
#  'exit1imbawax',
#  'drzammsydalo',
#  'upliftwarld2',
#  'metaiwargame',
#  'rplanatverif',
#  'rplanedverif',
#  'alienmworlds',
#  'alienwordlls',
#  'a1ieniwor1ds',
#  'a1ienvvordds',
#  'a1ienvvor1ds',
#  'a1iennwor1ds',
#  'upliftworlb2',
#  'elementcontc',
#  'japanmechadv',
#  'uplandcardss',
#  'chistofanfri',
#  'exitlimbowox',
#  'alieenwor1ds',
#  'qwertyytrewq',
#  'dustcoinmust',
#  'upiandscards',
#  'toppbaseball',
#  'memescartoon',
#  'skyseries123',
#  'rppppetverif',
#  'cryptowaifus',
#  'alingedwords',
#  'largexplsive',
#  'boysofsummur',
#  'thehorrorsss',
#  'playlistmuse',
#  'my3dadultart',
#  'bluewizardsn',
#  'samuraigirls',
#  'wondermonbot',
#  'piarsplanets',
#  'alienworidss',
#  'tokentoken11',
#  'aliemwworlds',
#  'whiteliisted',
#  'ailenwoorids',
#  'coronapandem',
#  'xxxxxxxxxxxa',
#  '12344dfhbdhf',
#  'al1enwor1dss',
#  'alienworklls',
#  'mlbtoppsball',
#  'rplannetpack',
#  'mlbttoppsver',
#  'petecardssss',
#  'mllbtoopppss',
#  'mlllbbtoopps',
#  'chituschitus',
#  'dogemoncards',
#  'mlbbtoppsver',
#  'mlbtoppsbase',
#  'aliemmworlds',
#  'alienworilds',
#  'boysofsummar',
#  'hodlgodverif',
#  'mlbtopppsver',
#  'mlbtopspsver',
#  'alienvvorlld',
#  'mlbtheshow21',
#  'mlbcollect21',
#  'mlbtooppsver',
#  'mlbtoppsvere',
#  'm1btoppsseer',
#  'toppsgodzlap',
#  'gpktoppsmoon',
#  'mlbtoppssver',
#  'boysofsumner',
#  'rplenetverif',
#  'mlbtoppsverf',
#  'mmlbtoppsver',
#  'girlinmy1chb',
#  'ailennworlds',
#  'exit11mbawax',
#  'alien1worids',
#  'alientworlds',
#  'reuploaddeut',
#  'zeugencorona',
#  'alliennworld',
#  'alleenworldd',
#  'allenworllds',
#  'alienpworlds',
#  'donateworlds',
#  'al1ienworlds',
#  'mllbtoppsnft',
#  'mlbtoppsveri',
#  'mllbtoppsver',
#  'mlbbtoppssgg',
#  'mlbstoppsver',
#  'mlbtoppsverl',
#  'm1akh4l1f4fa',
#  'mlvbtoppsver',
#  'mlbtoppsrvrr',
#  'kevinavadevs',
#  'mm1btoppsver',
#  'aliienvvorld',
#  'aliennwiorld',
#  'alieenworlld',
#  'aliienworids',
#  'mlbetoppsver',
#  'mlllbtopppps',
#  'playlistpoke',
#  'mbllltooppps',
#  'mlbqtoppsver',
#  'mlldoppsverr',
#  'mlbtoppppsss',
#  'mlbtoopppsss',
#  'mlbptoppsver',
#  'alinaworlids',
#  'mlbpremium21',
#  'mlbtooopppss',
#  'alienworldte',
#  'mlbtopppssss',
#  'mlbtoppsssss',
#  'alienwgames1',
#  'mlbktoppsver',
#  'ailenwooriis',
#  'toppslaunchd',
#  'mbltoppsssss',
#  'mlbbbbbtopps',
#  'mlbtoppsprem',
#  'mlbpooooppps',
#  'mibtooooppss',
#  'cb4bq.wam',
#  'nnptobbsvers',
#  'aliemvworlds',
#  'diberkatowax',
#  'mllllbtopsss',
#  'ailenwooridc',
#  'ujabq.wam',
#  'alienvvworld',
#  'aliecworldss',
#  'mlbtoppsnfts',
#  'mlbtoopsssss',
#  'toppclownsss',
#  'gamesofaline',
#  'mlllbttoppss',
#  'toppsforever',
#  'woodennickel',
#  'alienwor1ds1',
#  'kingonalinas',
#  'mlbttoplless',
#  'alienworldd1',
#  'mlbttoppless',
#  'kogsoff1cia1',
#  'triba1booksv',
#  'ml1btoppeese',
#  'mlbttopllles',
#  'rplanetpacks',
#  'alienpaworld',
#  'topcrappfail',
#  'alienwoldss1',
#  'mlbitoppsver',
#  'aliengame111',
#  'mlbtttooppps',
#  'mlbtttooopps',
#  'mlbbbtoppsss',
#  'razdva111111',
#  'mllbtopppsss',
#  'mllbttooppps',
#  'mmmlbltoppps',
#  'nbacurrent21',
#  'mlbbtopssggg',
#  '1stmmtzdesgn',
#  'zerrotwozerr',
#  'atomiccards1',
#  'digicardnfts',
#  'alienwoorild',
#  'mlbxtoppsver',
#  'aleienworlds',
#  'mlbctoppsver',
#  'mlvbtopssggs',
#  'onceptboxxx',
#  'alienswworld',
#  'strangerthin',
#  'ussrstampsjf',
#  'alienworids1',
#  'alienswordls',
#  'mllbttooppss',
#  'rplanettpack',
#  'mlbtoppsswax',
#  'mlbfakecards',
#  'cryptopixe1s',
#  'mlllbttoopps',
#  'allienwulrds',
#  'al1enwor1ds1',
#  'a1iienworlds',
#  'alienwoordsl',
#  'stndrddrller',
#  'alienworllld',
#  'allienworild',
#  'allienwoorld',
#  'alienworfdss',
#  'officialnfts',
#  'alienworldsz',
#  'aliemswworld',
#  '.ingaporepic',
#  'friendsicons',
#  'mllbtttoopps',
#  'mllllbtoopps',
#  'mllbbttoopps',
#  'rplanetspack',
#  'alienoworlds',
#  'mlllbtooppss',
#  'rplaneeettgg',
#  'aliensvworld',
#  'cryptoomonie',
#  'tumbrrrrrrrr',
#  'fromthephone',
#  'alienwuorlds',
#  'lynxartcoll1',
#  'al1ienworl1d',
#  'aliensvvorld',
#  'ascamdemic21',
#  'mutantssr2ve',
#  'mutantsrock2',
#  'nomutantrock',
#  'nomutantroc2',
#  'alienvwvorld',
#  'muutantsr2ve',
#  'a1ieenwor1ds',
#  'muttanttssr2',
#  'mutantwarrio',
#  'matuntssr2ve',
#  'allienwurlds',
#  'alienxworlds',
#  'alienwmorlds',
#  'alienwords23',
#  'lollitedoge1',
#  'madtowerarts',
#  'conceptvideo',
#  'fatboycrypto',
#  'al13nworlds1',
#  'cardscollect',
#  'holoddgoddgg',
#  'mutantsssr2g',
#  'aliienwordss',
#  'bitporncards',
#  'mllibtooppss',
#  'aliuworlldss',
#  'cryptocolect',
#  'kvmizumadeit',
#  'cyberbullyin',
#  'a1ienoworlds',
#  'al1ienworild',
#  'testcollecr4',
#  'rplanettland',
#  'mlbtttopppss',
#  'k1ltroartsss',
#  'alienswor1dz',
#  'colonizmaars',
#  'alienwworlld',
#  'aelianworlds',
#  'colonigemars',
#  'alieinwolrds',
#  'alienworldio',
#  'alienfworlds',
#  'wordlssalien',
#  'aliennwworld',
#  'alienworldns',
#  'ml1libtoopps',
#  'zi1rk.wam',
#  'avatarminers',
#  'narutoboruto',
#  'aliengworlds',
#  'alienswordss',
#  'alienwvvorld',
#  'ali1enworild',
#  'aleenvwordds',
#  'allennworlds',
#  'aliemvvorlds',
#  'aliemsworlds',
#  'alienworldzx',
#  'fansofalienw',
#  'aliensuuorld',
#  'worldsaliens',
#  'alienworld12',
#  'alienworleds',
#  'alienswaxhub',
#  'alienqworlds',
#  'worlddaliens',
#  'alienwwrolds',
#  'alienworldsm',
#  'alienworld11',
#  'alienworldsv',
#  'aliensworld1',
#  'a1lienwor1ds',
#  'standardpack',
#  'alienpworl1d',
#  'mutantrer2ra',
#  'm1btoppssver',
#  'alienvvvorld',
#  'alienworldcc',
#  'reebokreelok',
#  'calonizemars',
#  'colonizamars',
#  'colonisemars',
#  'ca1onezemers',
#  'colonlzamars',
#  'a1lienworild',
#  'weezeerpacks',
#  'weezeecllect',
#  'colonlzamors',
#  'wezerokhuman',
#  'vveeserverfi',
#  'co1onizemars',
#  'weezeerrpack',
#  'weezerweezer',
#  'weezeroffcal',
#  'weezerepacks',
#  'weezerpaacks',
#  'weezerofical',
#  'weezerwerivi',
#  'kelly1artwax',
#  'allemvvorlds',
#  'atbfinancial',
#  'mlbtoppsever',
#  'allensworlbs',
#  'weezzeerpack',
#  'weezeeroolls',
#  'mlllbtooppps',
#  'weezerveezer',
#  'weeezzerpack',
#  'allienlworld',
#  'allienworlld',
#  'alienvvorrld',
#  'mllbtoooppss',
#  'weezeerrshop',
#  'weazersshopp',
#  'colonizomars',
#  'mllbbtooopss',
#  'colonisemarz',
#  'weezzerrpack',
#  'weezzerpacks',
#  'weezervarifi',
#  'weezervvezer',
#  'alienvworlld',
#  'alienoworild',
#  'aliensswarss',
#  'alienzworlld',
#  'superaliensw',
#  'alienworld1o',
#  'alienworldz',
#  'oennbbiiwaam',
#  'rollplaanete',
#  'rpllanetpack',
#  'rplanetwerif',
#  'colonizimars',
#  'rpllaneetoff',
#  'rpllanettoff',
#  'rpllanetoffi',
#  'rplanetrplan',
#  'wweeezzeerrr',
#  'norrplanetpr',
#  'rolpllaanete',
#  'hodlgodhodll',
#  'jacobdegrom1',
#  '412342535423',
#  'saleoflaands',
#  'saleofflands',
#  'rplanetlands',
#  'alenvvvorlds',
#  'premiumpacks',
#  'rockycoastli',
#  'rpplanetmini',
#  'rplanatverlf',
#  'al1emvvorlds',
#  'rplanetstrue',
#  'rplaanettoff',
#  'weeezerpacks',
#  'rplaanetmini',
#  'shoprplanete',
#  'alensswordss',
#  'rpllanetmini',
#  'alienwarilds',
#  'norrplanettp',
#  'planetplanet',
#  'plaanettoffr',
#  'alianswordss',
#  'supplysrates',
#  'supplycrates',
#  'rpllanetofff',
#  'rpplanettoff',
#  'rpllaanetmin',
#  'alaenworldss',
#  'alienworldzs',
#  'weezeerpaack',
#  'rplanatvellf',
#  'rpplanetooff',
#  'rplenaterxxx',
#  'alienworldsx',
#  'alienvworldz',
#  'alienoworlts',
#  'alienchecked',
#  'alienwrailds',
#  'alkenworldss',
#  'ailensworlds',
#  'a1ienworldss',
#  'alianoworlds',
#  'alieroworlds',
#  'alliamworlds',
#  'fanartworlds',
#  'aliiemworlds',
#  'alllenworlds',
#  'aleenworldss',
#  'ali1enworlds',
#  'worldslands1',
#  'aliemworldss',
#  'aiienvworlds',
#  'allieenwords',
#  'rplanetveiif',
#  'lolchampsco1',
#  'metaforcemet',
#  'colomizenars',
#  'alienswdrlds',
#  'agentefaxagc',
#  'alkensworlds',
#  'alienllaands',
#  'weezercrypto',
#  'rplanemlandl',
#  'alieenllands',
#  'rplanetedual',
#  'rppllanneett',
#  'alieennworld',
#  'rplanattopps',
#  'rppllanetoff',
#  'conolizemars',
#  'exileecoffee',
#  'a11emvvorlds',
#  'rplanettofff',
#  'memecardsnft',
#  'colanizemars',
#  'weeezxershop',
#  'newworld2115',
#  'rpllanetdual',
#  'aliinvvorlds',
#  'alienworltts',
#  'rplanetlaand',
#  'rplanetlland',
#  'mlbtoppspack',
#  'ailenvvorlds',
#  'ailenwoorlis',
#  'alienworldfv',
#  'alienwordsof',
#  'alienwordsnf',
#  'alienwordszs',
#  'alientllmwax',
#  'alienxmorlds',
#  'alienwvorlld',
#  'alienworldsk',
#  '1alienworldz',
#  'mlbtoppsvgre',
#  'rplenatverif',
#  'weezarvrtrop',
#  'coloniznnars',
#  'rplanetminis',
#  'allienwortds',
#  'alllenvorlds',
#  'coloniizmars',
#  'nudeshotgirl',
#  'rplanetpaack',
#  'rplanetmines',
#  'rplanetveriv',
#  'rpplanetpaks',
#  'rplanetminni',
#  'rpplanetpack',
#  'a1iemvvor1ds',
#  'metaforcecry',
#  'meta1wargame',
#  'metatwargame',
#  'metalvargame',
#  'landsvvorlds',
#  'rplaanetpack',
#  'vveezercrypt',
#  'mlbpackstops',
#  'a11iemwor1ds',
#  'colonizemors',
#  'alieenlandes',
#  'alleneworlds',
#  'rplanetsshop',
#  'alienllannds',
#  'rpllanetemin',
#  'mlbtopptopps',
#  'rplanetvieff',
#  'aliennvvorld',
#  'weezervwezer',
#  'standaddrill',
#  'co1oniznnars',
#  'allworldcard',
#  'mlbtoppaacks',
#  'mlbtoppackss',
#  'alienworldtl',
#  'alieenlaands',
#  'aliernworlds',
#  'rplanetland4',
#  'co1oniemarss',
#  'rpllanetland',
#  'rpplanetland',
#  'metaforcever',
#  'metaforcetop',
#  'metallforcce',
#  'metamegforce',
#  'metaforcesle',
#  'metalfforrce',
#  'metametforce',
#  'metaforcesve',
#  'metaforcecee',
#  'metaforcevie',
#  'metaforceeee',
#  'metaforcemin',
#  'metaoforseve',
#  'rp1anetsshop',
#  'metafooorcee',
#  'mataforcevee',
#  'rpplenetland',
#  'allienvworld',
#  'mataforcever',
#  'nneta11falce',
#  'metaforcegam',
#  'metaforcenft',
#  'tradeofferer',
#  'tradeofferes',
#  'tradeofferss',
#  'rplanetarium',
#  'a11emvvor1ds',
#  'rplanetlends',
#  'xalienworlds',
#  'metaforcsell',
#  'metaforcecon',
#  'rmeta11forse',
#  'metatradeoff',
#  'allienlworls',
#  'co1onisemars',
#  'metaforcecom',
#  'vrfmeta1orce',
#  'rplanetminee',
#  'nftmetaforce',
#  'metaforcepac',
#  'metaforcepak',
#  'rplanatenfts',
#  'alienworldni',
#  'al1envvor1ds',
#  'alienworldsn',
#  'rppllaanetok',
#  'hodlmoonboyt',
#  'hodlmoonboyy',
#  'dasdas312312',
#  'stardate1111',
#  'alieanworild',
#  '1alienworld1',
#  'rplanatpacks',
#  'metaforcnfts',
#  'allienlandsi',
#  'mlbttoppsnft',
#  'rpplanettyet',
#  'aliensswords',
#  'alienworldst',
#  'alienworldse',
#  'a11emvwor1ds',
#  'alianworldss',
#  'rplanetlendn',
#  'alienworldna',
#  'alieniworlde',
#  'alienwor1ded',
#  'alienvvorlts',
#  'alienvworrld',
#  'alientoolstm',
#  'alienwoordls',
#  'worldaliens1',
#  'aliiienworld',
#  'allenaworlds',
#  'alienyworlds',
#  'aliemworldio',
#  'alllianworld',
#  'upworldlandv',
#  'allenssworks',
#  'earth2cards2',
#  'alienplanete',
#  'rplandsnftes',
#  'lorenzo1ontu',
#  'drawlloween1',
#  'rplandswills',
#  'cryptounoart',
#  'a1ilenworild',
#  'rplaneetpack',
#  'rplanetlandi',
#  'alienworldsp',
#  'alienworldsy',
#  'alienworldsq',
#  'alienworild1',
#  'vvorldsalien',
#  'alienwvorrld',
#  'alieenlendes',
#  'mlbtoppsshub',
#  'rplanetlande',
#  'alienworldsd',
#  'rplanetvarif',
#  'collectvvkey',
#  'rplanetsrare',
#  'rplanetverik',
#  'rplanetcards',
#  'mettafforcce',
#  'weezeerpack1',
#  'hodlmoonboya',
#  'yugiohfandom',
#  'aalenworldds',
#  'nottopshotss',
#  'aalenworldss',
#  'alienvvorld5',
#  'aliensworlde',
#  'prlanetverif',
#  'mlbpackstopi',
#  'co1on1zemars',
#  'alienworlddz',
#  'alienwor1dsa',
#  'alienworldsb',
#  'alienwori1ds',
#  'mlbtoppaccks',
#  'onlyfansnfts',
#  'rplanetlandm',
#  'a1ienvvorbls',
#  'alisdhiouior',
#  'rplanetveril',
#  'alienworldsl',
#  'rplanetcolle',
#  'darksinform1',
#  'alienwor1lds',
#  'mlbtopppackk',
#  'aliennlandst',
#  'allienlaands',
#  'alluenworrds',
#  'standarddril',
#  'binancewalle',
#  'xxxvideoxxxx',
#  '424234223342',
#  'germanidiots',
#  'rplanetland1',
#  'cryptopiece1',
#  'rplanetstack',
#  'bitcoinorgin',
#  'kennbosokgif',
#  'rplanetlandd',
#  'rplanetpackk',
#  'mlbishereeee',
#  'mlbplaysusus',
#  'mlbtoppssone',
#  ...]
