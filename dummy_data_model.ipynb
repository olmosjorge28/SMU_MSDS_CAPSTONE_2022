# %%
import pandas as pd
import numpy as np
from numpy.random import seed
from numpy.random import normal
from numpy.random import exponential

import torch
import torch.autograd as autograd
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor

import pytorch_lightning as pl
import seaborn as sns
from pylab import rcParams


import matplotlib.pyplot as plt
from matplotlib import rc
from matplotlib.ticker import MaxNLocator



from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

from multiprocessing import cpu_count
from pytorch_lightning.callbacks import ModelCheckpoint, EarlyStopping
from pytorch_lightning.loggers import TensorBoardLogger
from torchmetrics.functional import accuracy
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler



from keras.layers import Conv1D, Dense, Dropout, Input, Concatenate, GlobalMaxPooling1D, MaxPooling1D
from keras.models import Model
from tensorflow import keras
import tensorflow as tf
from sklearn.model_selection import StratifiedShuffleSplit

# from keras.optimizers import RMSprop, adam

# %% [markdown]
# ## Importing Data

# %%
day1_dataset_1min = pd.read_csv('Data Slices/5_days_timeseries_data/1min.csv')
day1_dataset_10min = pd.read_csv('Data Slices/5_days_timeseries_data/10min.csv')
day1_dataset_30min = pd.read_csv('Data Slices/5_days_timeseries_data/30min.csv')
day1_dataset_60min = pd.read_csv('Data Slices/5_days_timeseries_data/60min.csv')

# %%
def get_X_and_y(df, x_columns, y_columns):
    X = df[x_columns]
    y = df[y_columns]
    return X, y

# %%
def get_daily_sequences(X, y, feature_columns, sequence_dict = {}):
    for collection, group in X.groupby("collection"):
        features = group[group.columns.intersection(feature_columns)]
        blacklist = y[y.collection == collection].iloc[0].blacklisted
        if sequence_dict.get(collection):
            sequence_dict[collection][0].append(features)
        else:
            sequence_dict[collection] = ([features], blacklist)
    return sequence_dict

# %%
def get_daily_sequences(X, y, feature_columns, sequence_dict = {}):
    for collection, group in X.groupby("collection"):
        features = group[group.columns.intersection(feature_columns)]
        blacklist = y[y.collection == collection].iloc[0].blacklisted
        if sequence_dict.get(collection):
            sequence_dict[collection][0].append(features)
        else:
            sequence_dict[collection] = ([features], blacklist)
    return sequence_dict

# %%
def scale_dataset(sequences, columns = ['Price_USD', 'Price_Crypto', 'volume', 'density', 'vertex_count', 
                              'edge_count','vertext_edge_ratio'], fitted_scaler = None):
    collection_blacklist_dict = {sequence[0]:sequence[2] for sequence in sequences}
    concat_df = pd.concat([sequence[1] for sequence in sequences])
    if fitted_scaler is None:
        fitted_scaler = StandardScaler()
        fitted_scaler.fit(concat_df[columns])
    concat_df[columns] = fitted_scaler.transform(concat_df[columns])
    return  [(collection, group[columns], collection_blacklist_dict[collection]) 
             for collection, group in concat_df.groupby("collection")] , fitted_scaler

# %%
def get_all_sequences(all_df):
    sequence_dict = {}
    for df in all_df: 
        df = df.drop(['Unnamed: 0'], axis=1)
        x_columns =  ['Datetime_updated_seconds','Price_USD','Price_Crypto','volume','density',
                   'vertex_count','edge_count','collection']
        y_columns = ['blacklisted','collection']
        feature_columns=['Price_USD','Price_Crypto','volume',
                         'density', 'vertex_count','edge_count', 'collection', 'vertext_edge_ratio']
        X, y= get_X_and_y(df, x_columns, y_columns)
        X['vertext_edge_ratio'] = X['vertex_count']/X['edge_count']
        sequence_dict = get_daily_sequences(X, y, feature_columns, sequence_dict)
    return sequence_dict

# %%
def retrieve_all_train_test_sequences(all_df):
    train_test_sequences = []
    all_sequence_dict = list(get_all_sequences(all_df).items())
    
    x = [sequence for sequence in all_sequence_dict]
    y = [sequence[1][1] for sequence in all_sequence_dict]
    
    sss = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=1234)
         
    for train, test in  sss.split(x, y):
        X_train = [x[idx] for idx in train]
        X_test = [x[idx] for idx in test]
    return X_train, X_test

# %%
train_sequences, test_sequences = retrieve_all_train_test_sequences([day1_dataset_1min, day1_dataset_10min,
                                                                     day1_dataset_30min,
                                                                     day1_dataset_60min])
# Out:
# <ipython-input-7-ba7f0a36a736>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['vertext_edge_ratio'] = X['vertex_count']/X['edge_count']

# %%
def scale_train_test_sequences(train_sequences, test_sequences):
    scaled_train_dataset_dict = {}
    scaled_test_dataset_dict = {}
    scaled_train_dataset= []
    scaled_test_dataset= []
    length = len(train_sequences[0][1][0])
    for n in range(length):
        train_scaled, scaler = scale_dataset([(sequence[0], sequence[1][0][n], sequence[1][1]) for sequence in
                                              train_sequences])
        test_scaled, _ = scale_dataset([(sequence[0], sequence[1][0][n], sequence[1][1]) for sequence in
                                        test_sequences],
                      fitted_scaler= scaler)
        scaled_train_dataset.append(train_scaled)
        scaled_test_dataset.append(test_scaled)

    for scale_sequence in scaled_train_dataset:
        for collection in scale_sequence:
            if scaled_train_dataset_dict.get(collection[0]):
                scaled_train_dataset_dict[collection[0]][0].append(collection[1])
            else:
                scaled_train_dataset_dict[collection[0]] = ([collection[1]], collection[2])

    for scale_sequence in scaled_test_dataset:
        for collection in scale_sequence:
            if scaled_test_dataset_dict.get(collection[0]):
                scaled_test_dataset_dict[collection[0]][0].append(collection[1])
            else:
                scaled_test_dataset_dict[collection[0]] = ([collection[1]], collection[2])
                
    return list(scaled_train_dataset_dict.values()), list(scaled_test_dataset_dict.values())

# %%
train_values, test_values = scale_train_test_sequences(train_sequences,test_sequences)

# %%
test_values[7][0][0]
# Out:
#         Price_USD  Price_Crypto    volume   density  vertex_count  edge_count  \
# 144000  -0.210093     -0.231693  6.716017  1.384928     -0.298881   -0.229725
# 144001  -0.210093     -0.231693 -0.046785  1.384928     -0.298881   -0.229725
# 144002  -0.210093     -0.231693 -0.046785  1.384928     -0.298881   -0.229725
# 144003  -0.210093     -0.231693 -0.046785  1.384928     -0.298881   -0.229725
# 144004  -0.210093     -0.231693 -0.046785  1.384928     -0.298881   -0.229725
# ...           ...           ...       ...       ...           ...         ...
# 151195  -0.213662     -0.234063 -0.046785  1.384928     -0.298881   -0.229725
# 151196  -0.213662     -0.234063 -0.046785  1.384928     -0.298881   -0.229725
# 151197  -0.213662     -0.234063 -0.046785  1.384928     -0.298881   -0.229725
# 151198  -0.213662     -0.234063 -0.046785  1.384928     -0.298881   -0.229725
# 151199  -0.213662     -0.234063 -0.046785  1.384928     -0.298881   -0.229725
#
#         vertext_edge_ratio
# 144000            1.267608
# 144001            1.267608
# 144002            1.267608
# 144003            1.267608
# 144004            1.267608
# ...                    ...
# 151195            1.267608
# 151196            1.267608
# 151197            1.267608
# 151198            1.267608
# 151199            1.267608
#
# [7200 rows x 7 columns]

# %%
train_values[356][0][0]
# Out:
#          Price_USD  Price_Crypto     volume   density  vertex_count  \
# 3254400  -0.215687     -0.191410  13.478818  0.466310     -0.274622
# 3254401  -0.211617     -0.191410  20.241620 -0.268584     -0.226104
# 3254402  -0.209892     -0.191410  13.478818 -0.452308     -0.201846
# 3254403  -0.201095     -0.167714  20.241620 -0.583539     -0.177587
# 3254404  -0.201198     -0.171663  20.241620 -0.583539     -0.177587
# ...            ...           ...        ...       ...           ...
# 3261595  -0.201577     -0.191410  -0.046785 -1.046708      0.065001
# 3261596  -0.201577     -0.191410  -0.046785 -1.046708      0.065001
# 3261597  -0.201577     -0.191410  -0.046785 -1.046708      0.065001
# 3261598  -0.201577     -0.191410  -0.046785 -1.046708      0.065001
# 3261599  -0.201577     -0.191410  -0.046785 -1.046708      0.065001
#
#          edge_count  vertext_edge_ratio
# 3254400   -0.212204           -0.036901
# 3254401   -0.177164           -0.689156
# 3254402   -0.159644           -0.819607
# 3254403   -0.142123           -0.906574
# 3254404   -0.142123           -0.906574
# ...             ...                 ...
# 3261595    0.033079           -1.178347
# 3261596    0.033079           -1.178347
# 3261597    0.033079           -1.178347
# 3261598    0.033079           -1.178347
# 3261599    0.033079           -1.178347
#
# [7200 rows x 7 columns]

# %% [markdown]
# ## Model

# %%
train_values = list(scaled_train_dataset_dict.values())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-a9ac1955ba45> in <module>
# ----> 1 train_values = list(scaled_train_dataset_dict.values())
#
# NameError: name 'scaled_train_dataset_dict' is not defined

# %%
test_values = list(scaled_test_dataset_dict.values())

# %%
len(train_values[0][0])
# Out:
# 4

# %%
for n in range(len(train_values[0][0])):
    print(n)
# Out:
# 0
# 1
# 2
# 3

# %%
model_shapes = [train_values[0][0][n].shape for n in range(len(train_values[0][0]))]

# %%
model_shapes
# Out:
# [(1440, 1)]

# %%
filters = [200]
k_sizes = [100]

# %%
def get_base_model(shape, k_size = k_sizes[0], num_filters = filters[0]):
    print("base model shape", shape)
    input_seq = Input(shape=shape)
    nb_filters = num_filters
    convolved = Conv1D(num_filters, k_size, padding="same", activation="relu")(input_seq)
    processed = GlobalMaxPooling1D()(convolved)
    #todo: fix maxpooling
#     processed = MaxPooling1D(pool_size=2, strides=1, padding='same')(convolved)
    compressed = Dense(100, activation="relu")(processed)
    compressed = Dropout(0.3)(compressed)
    model = Model(inputs=input_seq, outputs=compressed)
    model.summary()
    return model

# %%
def main_model(shapes, filters, k_sizes):
    inputs = [Input(shape=shape, name=f'input{n}')for n, shape in enumerate(shapes)]
    sub_models = [ get_base_model(shape, k_size = k_sizes[n], num_filters=filters[n]) 
                  for n, shape in enumerate(shapes)]
    print(sub_models[0].output)
    embeddings = [ model(inputs[n]) for n, model in enumerate(sub_models)]
    merged = Concatenate()(embeddings)
    #todo: tweak dense be modifiable 
    layer1 = Dense(100, activation='relu', name ='hidden_layer1')(merged)
    layer2 = Dense(50, activation='relu', name ='hidden_layer2')(layer1)
    layer3 = Dense(25, activation='relu', name ='hidden_layer3')(layer2)
    out = Dense(1, activation='sigmoid')(layer3)
    model = Model(inputs=inputs, outputs=out)
    return model

# %%
def run_model(train, validation, model_shapes, filters, k_sizes):
    es = keras.callbacks.EarlyStopping(min_delta=0.00001, patience=20)
    model = main_model(model_shapes, filters, k_sizes)
    model.compile(loss='binary_crossentropy', # categorical_crossentropy
                          optimizer='adam', #sgd, nadam, adam, rmsprop
                          metrics=['binary_accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall(),
                                   tf.keras.metrics.AUC(curve='PR')])
    model.summary()
    model_hist = model.fit(train,
                               validation_data=validation,
                               batch_size=200, epochs=2000, 
                           callbacks=[es]
                          )
    return model_hist, model

# %%
def get_formatted_inputs(values):
    x_train_arr = []
    length = len(values)
    for n in range(len(values[0][0])):
        x_train = [sequence[0][n] for sequence in values]
        shape = x_train[0].shape
        x_train =  np.stack(x_train)
        x_train = x_train.reshape(length, shape[0], shape[1])
        x_train_arr.append(x_train)
    return x_train_arr, [sequence[1] for sequence in values]

# %%
def retrieve_tensor_datasets(train, test):
    formatted_train = ({f'input{n}': data for n, data in enumerate(train[0]) }, train[1])
    formatted_test = ({f'input{n}': data for n, data in enumerate(test[0]) }, test[1])
    train_dataset = tf.data.Dataset.from_tensor_slices(formatted_train).batch(200)
    test_dataset = tf.data.Dataset.from_tensor_slices(formatted_test).batch(200)
    return train_dataset, test_dataset

# %%
dataset, validation = retrieve_tensor_datasets(get_formatted_inputs(train_values),
                                               get_formatted_inputs(test_values) )

# %%
model_hist, model = run_model(dataset, validation, model_shapes, filters, k_sizes)
# Out:
# base model shape (1440, 1)
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 1440, 1)]         0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 1440, 200)         20200
# _________________________________________________________________
# global_max_pooling1d (Global (None, 200)               0
# _________________________________________________________________
# dense (Dense)                (None, 100)               20100
# _________________________________________________________________
# dropout (Dropout)            (None, 100)               0
# =================================================================
# Total params: 40,300
# Trainable params: 40,300
# Non-trainable params: 0
# _________________________________________________________________
# KerasTensor(type_spec=TensorSpec(shape=(None, 100), dtype=tf.float32, name=None), name='dropout/Identity:0', description="created by layer 'dropout'")
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input0 (InputLayer)          [(None, 1440, 1)]         0
# _________________________________________________________________
# model (Functional)           (None, 100)               40300
# _________________________________________________________________
# concatenate (Concatenate)    (None, 100)               0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 100)               10100
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 50)                5050
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 25)                1275
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 26
# =================================================================
# Total params: 56,751
# Trainable params: 56,751
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/2000
# 1/1 [==============================] - 2s 2s/step - loss: 2.1910 - binary_accuracy: 0.8000 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.1857 - val_loss: 2.9143 - val_binary_accuracy: 0.2000 - val_precision: 0.2000 - val_recall: 1.0000 - val_auc: 0.7056
# Epoch 2/2000
# 1/1 [==============================] - 0s 288ms/step - loss: 1.7369 - binary_accuracy: 0.3875 - precision: 0.2203 - recall: 0.8125 - auc: 0.2662 - val_loss: 0.5324 - val_binary_accuracy: 0.8000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 1.0000
# Epoch 3/2000
# 1/1 [==============================] - 0s 218ms/step - loss: 0.6592 - binary_accuracy: 0.8125 - precision: 0.6667 - recall: 0.1250 - auc: 0.4115 - val_loss: 0.5674 - val_binary_accuracy: 0.8000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 1.0000
# Epoch 4/2000
# 1/1 [==============================] - 0s 246ms/step - loss: 0.7672 - binary_accuracy: 0.8125 - precision: 1.0000 - recall: 0.0625 - auc: 0.4237 - val_loss: 0.1964 - val_binary_accuracy: 0.8000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 1.0000
# Epoch 5/2000
# 1/1 [==============================] - 0s 231ms/step - loss: 0.6580 - binary_accuracy: 0.8375 - precision: 1.0000 - recall: 0.1875 - auc: 0.4343 - val_loss: 0.2450 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 6/2000
# 1/1 [==============================] - 0s 227ms/step - loss: 0.5178 - binary_accuracy: 0.7250 - precision: 0.3125 - recall: 0.3125 - auc: 0.4519 - val_loss: 0.4511 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 7/2000
# 1/1 [==============================] - 0s 280ms/step - loss: 0.5073 - binary_accuracy: 0.7375 - precision: 0.4138 - recall: 0.7500 - auc: 0.5396 - val_loss: 0.1609 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 8/2000
# 1/1 [==============================] - 0s 285ms/step - loss: 0.4051 - binary_accuracy: 0.8375 - precision: 0.6154 - recall: 0.5000 - auc: 0.6812 - val_loss: 0.0748 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 9/2000
# 1/1 [==============================] - 0s 242ms/step - loss: 0.4600 - binary_accuracy: 0.9000 - precision: 1.0000 - recall: 0.5000 - auc: 0.6623 - val_loss: 0.0790 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 10/2000
# 1/1 [==============================] - 0s 259ms/step - loss: 0.5143 - binary_accuracy: 0.8500 - precision: 1.0000 - recall: 0.2500 - auc: 0.6487 - val_loss: 0.0480 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 11/2000
# 1/1 [==============================] - 0s 222ms/step - loss: 0.3105 - binary_accuracy: 0.8750 - precision: 0.8750 - recall: 0.4375 - auc: 0.7915 - val_loss: 0.0505 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 12/2000
# 1/1 [==============================] - 0s 255ms/step - loss: 0.2045 - binary_accuracy: 0.9375 - precision: 1.0000 - recall: 0.6875 - auc: 0.8878 - val_loss: 0.0404 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 13/2000
# 1/1 [==============================] - 0s 265ms/step - loss: 0.0994 - binary_accuracy: 0.9625 - precision: 0.9333 - recall: 0.8750 - auc: 0.9888 - val_loss: 0.0193 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 14/2000
# 1/1 [==============================] - 0s 198ms/step - loss: 0.1548 - binary_accuracy: 0.9250 - precision: 0.7778 - recall: 0.8750 - auc: 0.9434 - val_loss: 0.0081 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 15/2000
# 1/1 [==============================] - 0s 263ms/step - loss: 0.1178 - binary_accuracy: 0.9750 - precision: 0.8889 - recall: 1.0000 - auc: 0.9726 - val_loss: 0.0023 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 16/2000
# 1/1 [==============================] - 0s 254ms/step - loss: 0.0508 - binary_accuracy: 0.9875 - precision: 0.9412 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0011 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 17/2000
# 1/1 [==============================] - 0s 281ms/step - loss: 0.0543 - binary_accuracy: 0.9875 - precision: 1.0000 - recall: 0.9375 - auc: 0.9929 - val_loss: 0.0011 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 18/2000
# 1/1 [==============================] - 0s 206ms/step - loss: 0.0766 - binary_accuracy: 0.9625 - precision: 1.0000 - recall: 0.8125 - auc: 1.0000 - val_loss: 6.3725e-04 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 19/2000
# 1/1 [==============================] - 0s 326ms/step - loss: 0.1133 - binary_accuracy: 0.9500 - precision: 1.0000 - recall: 0.7500 - auc: 0.9981 - val_loss: 2.2827e-04 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 20/2000
# 1/1 [==============================] - 0s 206ms/step - loss: 0.0515 - binary_accuracy: 0.9750 - precision: 0.9375 - recall: 0.9375 - auc: 0.9929 - val_loss: 9.5170e-05 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 21/2000
# 1/1 [==============================] - 0s 247ms/step - loss: 0.0132 - binary_accuracy: 0.9875 - precision: 1.0000 - recall: 0.9375 - auc: 1.0000 - val_loss: 5.2690e-05 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 22/2000
# 1/1 [==============================] - 0s 302ms/step - loss: 0.0129 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 3.7235e-05 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 23/2000
# 1/1 [==============================] - 0s 224ms/step - loss: 0.0137 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 2.9237e-05 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 24/2000
# 1/1 [==============================] - 0s 227ms/step - loss: 0.0042 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 2.4757e-05 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 25/2000
# 1/1 [==============================] - 0s 322ms/step - loss: 0.0107 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 2.0397e-05 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 26/2000
# 1/1 [==============================] - 0s 212ms/step - loss: 0.0043 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 1.7494e-05 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 27/2000
# 1/1 [==============================] - 0s 323ms/step - loss: 0.0123 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 1.4337e-05 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 28/2000
# 1/1 [==============================] - 0s 222ms/step - loss: 0.0019 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 1.1807e-05 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 29/2000
# 1/1 [==============================] - 0s 194ms/step - loss: 0.0041 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 9.5852e-06 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 30/2000
# 1/1 [==============================] - 0s 316ms/step - loss: 0.0038 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 7.5956e-06 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 31/2000
# 1/1 [==============================] - 0s 223ms/step - loss: 0.0015 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 6.0508e-06 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 32/2000
# 1/1 [==============================] - 0s 224ms/step - loss: 6.1414e-04 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 4.8835e-06 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 33/2000
# 1/1 [==============================] - 0s 235ms/step - loss: 4.5378e-04 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 3.9946e-06 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 34/2000
# 1/1 [==============================] - 0s 219ms/step - loss: 0.0015 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 3.2646e-06 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 35/2000
# 1/1 [==============================] - 0s 227ms/step - loss: 0.0045 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 2.6204e-06 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 36/2000
# 1/1 [==============================] - 0s 231ms/step - loss: 0.0050 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 2.0485e-06 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 37/2000
# 1/1 [==============================] - 0s 232ms/step - loss: 0.0028 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 1.6596e-06 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 38/2000
# 1/1 [==============================] - 0s 204ms/step - loss: 0.0013 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 1.3396e-06 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 39/2000
# 1/1 [==============================] - 0s 213ms/step - loss: 5.3128e-05 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 1.1004e-06 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 40/2000
# 1/1 [==============================] - 0s 216ms/step - loss: 3.5171e-04 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 9.0687e-07 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 41/2000
# 1/1 [==============================] - 0s 218ms/step - loss: 0.0013 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 7.5179e-07 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 42/2000
# 1/1 [==============================] - 0s 245ms/step - loss: 5.5033e-05 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 6.3451e-07 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 43/2000
# 1/1 [==============================] - 0s 233ms/step - loss: 1.6336e-04 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 5.4415e-07 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 44/2000
# 1/1 [==============================] - 0s 205ms/step - loss: 4.4810e-04 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 4.6591e-07 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 45/2000
# 1/1 [==============================] - 0s 234ms/step - loss: 0.0025 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 4.1163e-07 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 46/2000
# 1/1 [==============================] - 0s 213ms/step - loss: 1.5566e-05 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 3.6798e-07 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 47/2000
# 1/1 [==============================] - 0s 237ms/step - loss: 6.2979e-04 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 3.2765e-07 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 48/2000
# 1/1 [==============================] - 0s 239ms/step - loss: 0.0016 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 2.9076e-07 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 49/2000
# 1/1 [==============================] - 0s 252ms/step - loss: 3.1599e-05 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 2.6169e-07 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 50/2000
# 1/1 [==============================] - 0s 206ms/step - loss: 3.3015e-04 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 2.3750e-07 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 51/2000
# 1/1 [==============================] - 0s 205ms/step - loss: 2.2081e-05 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 2.1873e-07 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 52/2000
# 1/1 [==============================] - 0s 217ms/step - loss: 1.0087e-04 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 2.0306e-07 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 53/2000
# 1/1 [==============================] - 0s 199ms/step - loss: 7.9046e-04 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 1.8950e-07 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000

# %%
prediction[prediction <=0.5] = 0
prediction[prediction >0.5] = 1

# %%
[pred[0] for pred in prediction.tolist()]

# %%
def plot_training_curves(history, title=None):
    ''' Plot the training curves for loss and accuracy given a model history
    '''
    # find the minimum loss epoch
    minimum = np.min(history.history['val_loss'])
    min_loc = np.where(minimum == history.history['val_loss'])[0]
    # get the vline y-min and y-max
    loss_min, loss_max = (min(history.history['val_loss'] + history.history['loss']),
                          max(history.history['val_loss'] + history.history['loss']))
    acc_min, acc_max = (min(history.history['val_binary_accuracy'] + history.history['binary_accuracy']),
                        max(history.history['val_binary_accuracy'] + history.history['binary_accuracy']))
    # create figure
    fig, ax = plt.subplots(ncols=2, figsize = (15,7))
    fig.suptitle(title)
    index = np.arange(1, len(history.history['binary_accuracy']) + 1)
    # plot the loss and validation loss
    ax[0].plot(index, history.history['loss'], label = 'loss')
    ax[0].plot(index, history.history['val_loss'], label = 'val_loss')
    ax[0].vlines(min_loc + 1, loss_min, loss_max, label = 'min_loss_location')
    ax[0].set_title('Loss')
    ax[0].set_ylabel('Loss')
    ax[0].set_xlabel('Epochs')
    ax[0].legend()
    # plot the accuracy and validation accuracy
    ax[1].plot(index, history.history['binary_accuracy'], label = 'accuracy')
    ax[1].plot(index, history.history['val_binary_accuracy'], label = 'val_accuracy')
    ax[1].vlines(min_loc + 1, acc_min, acc_max, label = 'min_loss_location')
    ax[1].set_title('Accuracy')
    ax[1].set_ylabel('Accuracy')
    ax[1].set_xlabel('Epochs')
    ax[1].legend()
    plt.show()

# %%
def plot_training_curves_auc(history, title=None):
    ''' Plot the training curves for loss and accuracy given a model history
    '''
    # find the minimum loss epoch
    minimum = np.min(history.history['val_loss'])
    min_loc = np.where(minimum == history.history['val_loss'])[0]
    # get the vline y-min and y-max
    loss_min, loss_max = (min(history.history['val_loss'] + history.history['loss']),
                          max(history.history['val_loss'] + history.history['loss']))
    acc_min, acc_max = (min(history.history['val_auc'] + history.history['auc']),
                        max(history.history['val_auc'] + history.history['auc']))
    # create figure
    fig, ax = plt.subplots(ncols=2, figsize = (15,7))
    fig.suptitle(title)
    index = np.arange(1, len(history.history['auc']) + 1)
    # plot the loss and validation loss
    ax[0].plot(index, history.history['loss'], label = 'loss')
    ax[0].plot(index, history.history['val_loss'], label = 'val_loss')
    ax[0].vlines(min_loc + 1, loss_min, loss_max, label = 'min_loss_location')
    ax[0].set_title('Loss')
    ax[0].set_ylabel('Loss')
    ax[0].set_xlabel('Epochs')
    ax[0].legend()
    # plot the accuracy and validation accuracy
    ax[1].plot(index, history.history['auc'], label = 'auc')
    ax[1].plot(index, history.history['val_auc'], label = 'val_auc')
    ax[1].vlines(min_loc + 1, acc_min, acc_max, label = 'min_loss_location')
    ax[1].set_title('AUC')
    ax[1].set_ylabel('auc')
    ax[1].set_xlabel('Epochs')
    ax[1].legend()
    plt.show()

# %%
plot_training_curves(history=model_hist)

# %%
plot_training_curves_auc(history=model_hist)

# %%
# Out:
# array([-0.12373786, -0.3946075 ,  1.8864716 , ..., -1.04683539,
#        -0.31209261,  0.86439332])

# %%
import matplotlib.pyplot as plt

plt.show()

# %%
arr = np.array(count)

# %%
bins
# Out:
# array([-4.36245984, -4.35651201, -4.35056418, ...,  4.19051944,
#         4.19646727,  4.2024151 ])

# %%
arr
# Out:
# array([1., 0., 0., ..., 0., 0., 1.])

# %%
def fill_zeros_with_last(arr):
    prev = np.arange(len(arr))
    prev[arr == 0] = 0
    prev = np.maximum.accumulate(prev)
    return arr[prev]

# %%
def generate_blacklisted(times, func):
    all_blacklisted = []
    for _ in range(times):
        data = func(loc=0, scale=1, size=1440*30)
        count, bins, ignored = plt.hist(data, 1440)
        all_blacklisted.append(fill_zeros_with_last(count))
    return all_blacklisted

# %%
def generate_whitelisted(times, func):
    all_blacklisted = []
    for _ in range(times):
        data = func(3.14159, size=1440*10)
        count, bins, ignored = plt.hist(data, 1440)
        all_blacklisted.append(fill_zeros_with_last(count))
    return all_blacklisted

# %%
sample_blacklisted = generate_blacklisted(20, normal)

# %%
sample_exponential = generate_whitelisted(80, exponential)

# %%
# sample_blacklisted = numpy.array(sample_blaclisted)
blacklisted_dataframes = [([pd.DataFrame(arr, columns = ['data'])], 1) for arr in sample_blacklisted]

# %%
whitelisted_dataframes = [([pd.DataFrame(arr, columns = ['data'])], 0) for arr in sample_exponential]

# %%
blacklisted_dataframes[0][0]
# Out:
# [      data
#  0      1.0
#  1      1.0
#  2      1.0
#  3      1.0
#  4      1.0
#  ...    ...
#  1435   1.0
#  1436   1.0
#  1437   1.0
#  1438   1.0
#  1439   1.0
#
#  [1440 rows x 1 columns]]

# %%
def retrieve_all_train_test_sequences(all_sequence_dict):   
    x = [sequence for sequence in all_sequence_dict]
    y = [sequence[1] for sequence in all_sequence_dict]
    
    sss = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=1234)
         
    for train, test in  sss.split(x, y):
        X_train = [x[idx] for idx in train]
        X_test = [x[idx] for idx in test]
    return X_train, X_test

# %%
train_values, test_values = retrieve_all_train_test_sequences(blacklisted_dataframes+whitelisted_dataframes)

# %%
sample_sample_exponential = numpy.array(sample_exponential)
pd.DataFrame(sample_exponential, columns = ['data'])

# %%
plt.title("Line graph")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.plot(np.array([n for n in range(1440)]), sample_blaclisted[150], color ="red")
plt.show()

# %%
import os
import glob

# %%
path =  os.getcwd()+'/Data Slices/5_days_all_metrics'
csv_files = glob.glob(os.path.join(path, "*.csv"))
my_dict = {}
  
# loop over the list of csv files
for f in csv_files:
      
    # read the csv file
    df = pd.read_csv(f)
    
    
    # print the location and filename
    print('Location:', f)
    print('File Name:', f.split("/")[-1])
    
    my_dict[f.split("/")[-1]] = df
    # print the content
    print('Content:')
#     display(df)
    print()
# Out:
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/space1catzzz.csv
# File Name: space1catzzz.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/seven1111111.csv
# File Name: seven1111111.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/alienwmorlds.csv
# File Name: alienwmorlds.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/trocproclock.csv
# File Name: trocproclock.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/alienswordls.csv
# File Name: alienswordls.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/aliennwiorld.csv
# File Name: aliennwiorld.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/crypto5tache.csv
# File Name: crypto5tache.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/strattonsire.csv
# File Name: strattonsire.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/twobontanica.csv
# File Name: twobontanica.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/bratz.csv
# File Name: bratz.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/doodleartoon.csv
# File Name: doodleartoon.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/dualvoidgifs.csv
# File Name: dualvoidgifs.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/shatnertweet.csv
# File Name: shatnertweet.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/alien.worlds.csv
# File Name: alien.worlds.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/spacequbeadv.csv
# File Name: spacequbeadv.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/ninetartnfts.csv
# File Name: ninetartnfts.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/tenminuteart.csv
# File Name: tenminuteart.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/steampunk121.csv
# File Name: steampunk121.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/conceptboxxx.csv
# File Name: conceptboxxx.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/anthon1hurdy.csv
# File Name: anthon1hurdy.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/allienwurlds.csv
# File Name: allienwurlds.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/krstarcharts.csv
# File Name: krstarcharts.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/nftsgeniusxv.csv
# File Name: nftsgeniusxv.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/byjohnhunter.csv
# File Name: byjohnhunter.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/imtwerkypepe.csv
# File Name: imtwerkypepe.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/a1ienzworlds.csv
# File Name: a1ienzworlds.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/blkchancards.csv
# File Name: blkchancards.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/nanacollecta.csv
# File Name: nanacollecta.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/roardigiarts.csv
# File Name: roardigiarts.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/fantasypsnts.csv
# File Name: fantasypsnts.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/aliemwworlds.csv
# File Name: aliemwworlds.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/badges.b1.csv
# File Name: badges.b1.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/aliengworlds.csv
# File Name: aliengworlds.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/myfirstcards.csv
# File Name: myfirstcards.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/digitalblock.csv
# File Name: digitalblock.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/astrocutties.csv
# File Name: astrocutties.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/1forthebirds.csv
# File Name: 1forthebirds.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/goodvibesart.csv
# File Name: goodvibesart.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/cooolaidtest.csv
# File Name: cooolaidtest.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/yetigraffiti.csv
# File Name: yetigraffiti.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/momentintime.csv
# File Name: momentintime.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/fatboycrypto.csv
# File Name: fatboycrypto.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/cardseriess1.csv
# File Name: cardseriess1.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/3dpixelbadge.csv
# File Name: 3dpixelbadge.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/fractaplanet.csv
# File Name: fractaplanet.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/jesusnft1234.csv
# File Name: jesusnft1234.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/autowildnfts.csv
# File Name: autowildnfts.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/alienfansart.csv
# File Name: alienfansart.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/noacollector.csv
# File Name: noacollector.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/dgevangelist.csv
# File Name: dgevangelist.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/aleienworlds.csv
# File Name: aleienworlds.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/sketchsquad1.csv
# File Name: sketchsquad1.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/testcollecr4.csv
# File Name: testcollecr4.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/pepe.hero.csv
# File Name: pepe.hero.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/e2premiumnft.csv
# File Name: e2premiumnft.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/mattborchert.csv
# File Name: mattborchert.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/collectemall.csv
# File Name: collectemall.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/pilsinupland.csv
# File Name: pilsinupland.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/gir1slovenft.csv
# File Name: gir1slovenft.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/pixelwooorms.csv
# File Name: pixelwooorms.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/sp1lecomdon1.csv
# File Name: sp1lecomdon1.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/pixeledfaces.csv
# File Name: pixeledfaces.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/a1ienoworlds.csv
# File Name: a1ienoworlds.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/bitspacecryp.csv
# File Name: bitspacecryp.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/cryptooil111.csv
# File Name: cryptooil111.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/tapedamagetv.csv
# File Name: tapedamagetv.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/upland1cards.csv
# File Name: upland1cards.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/swagboardsds.csv
# File Name: swagboardsds.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/pixelhistory.csv
# File Name: pixelhistory.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/nvenomsnftzs.csv
# File Name: nvenomsnftzs.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/rgbirenecruz.csv
# File Name: rgbirenecruz.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/spiralsplash.csv
# File Name: spiralsplash.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/artbyhuddo21.csv
# File Name: artbyhuddo21.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/mlbtopppsver.csv
# File Name: mlbtopppsver.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/cursescurses.csv
# File Name: cursescurses.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/nftboxing123.csv
# File Name: nftboxing123.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/zippergirls1.csv
# File Name: zippergirls1.csv
# Content:
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/drzammsydolo.csv
# File Name: drzammsydolo.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/simagigit453.csv
# File Name: simagigit453.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/proartgalley.csv
# File Name: proartgalley.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/mddeesignerr.csv
# File Name: mddeesignerr.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/ikimonoworld.csv
# File Name: ikimonoworld.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/driiiipstars.csv
# File Name: driiiipstars.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/fanaticsuno1.csv
# File Name: fanaticsuno1.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/skatecoinwax.csv
# File Name: skatecoinwax.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/freehongkong.csv
# File Name: freehongkong.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/virtualdream.csv
# File Name: virtualdream.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/virginscards.csv
# File Name: virginscards.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/nexusdigital.csv
# File Name: nexusdigital.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/anytasknifty.csv
# File Name: anytasknifty.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/bluewizardsn.csv
# File Name: bluewizardsn.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/springtrain1.csv
# File Name: springtrain1.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/starcardscpt.csv
# File Name: starcardscpt.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/waxpackfiend.csv
# File Name: waxpackfiend.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/producepeeps.csv
# File Name: producepeeps.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/codamecrypto.csv
# File Name: codamecrypto.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/parisartwork.csv
# File Name: parisartwork.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/mrriro3darts.csv
# File Name: mrriro3darts.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/3dnanoocards.csv
# File Name: 3dnanoocards.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/cryptowaifus.csv
# File Name: cryptowaifus.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/visionarynft.csv
# File Name: visionarynft.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/ultrarare.csv
# File Name: ultrarare.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/alienwvvorld.csv
# File Name: alienwvvorld.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/manusonqncol.csv
# File Name: manusonqncol.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/placeitsupzc.csv
# File Name: placeitsupzc.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/metaforce.csv
# File Name: metaforce.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/plartcollect.csv
# File Name: plartcollect.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/microworlds1.csv
# File Name: microworlds1.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/mmlbtoppsver.csv
# File Name: mmlbtoppsver.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/cric.owens.csv
# File Name: cric.owens.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/urbantexture.csv
# File Name: urbantexture.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/fuzzykitten1.csv
# File Name: fuzzykitten1.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/fundotxcutie.csv
# File Name: fundotxcutie.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/happytokillu.csv
# File Name: happytokillu.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/515toysinthe.csv
# File Name: 515toysinthe.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/hollowoodddd.csv
# File Name: hollowoodddd.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/uplandhubnft.csv
# File Name: uplandhubnft.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/ethermineeee.csv
# File Name: ethermineeee.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/nonfngbgirls.csv
# File Name: nonfngbgirls.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/crptomonkeys.csv
# File Name: crptomonkeys.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/maikis1anfts.csv
# File Name: maikis1anfts.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/seeingnft111.csv
# File Name: seeingnft111.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/3dartdesigne.csv
# File Name: 3dartdesigne.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/humbledrawin.csv
# File Name: humbledrawin.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/cryptoflash1.csv
# File Name: cryptoflash1.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/mediumformat.csv
# File Name: mediumformat.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/alienvvorlld.csv
# File Name: alienvvorlld.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/freefiregame.csv
# File Name: freefiregame.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/abstracts1sm.csv
# File Name: abstracts1sm.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/midtownatlga.csv
# File Name: midtownatlga.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/alienwordlls.csv
# File Name: alienwordlls.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/k1ltroartsss.csv
# File Name: k1ltroartsss.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/thederpycats.csv
# File Name: thederpycats.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/mllbttooppss.csv
# File Name: mllbttooppss.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/monalisanft1.csv
# File Name: monalisanft1.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/magiccmullet.csv
# File Name: magiccmullet.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/gifartonwax1.csv
# File Name: gifartonwax1.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/mykidcandraw.csv
# File Name: mykidcandraw.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/realmyaucats.csv
# File Name: realmyaucats.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/stackofcards.csv
# File Name: stackofcards.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/rplanet.csv
# File Name: rplanet.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/blackmoney12.csv
# File Name: blackmoney12.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/udogoodstuff.csv
# File Name: udogoodstuff.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/aiienworldss.csv
# File Name: aiienworldss.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/dayakorigins.csv
# File Name: dayakorigins.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/nfthypealbum.csv
# File Name: nfthypealbum.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/wolfensnfts1.csv
# File Name: wolfensnfts1.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/mifamiliavwv.csv
# File Name: mifamiliavwv.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/byronartset1.csv
# File Name: byronartset1.csv
# Content:
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/alienftshelk.csv
# File Name: alienftshelk.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/flegandsnfts.csv
# File Name: flegandsnfts.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/gybniftyclub.csv
# File Name: gybniftyclub.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/wizardcrdgme.csv
# File Name: wizardcrdgme.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/missteennfts.csv
# File Name: missteennfts.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/lurk24dotcom.csv
# File Name: lurk24dotcom.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/dpsafecolors.csv
# File Name: dpsafecolors.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/bitversevere.csv
# File Name: bitversevere.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/offroadpaint.csv
# File Name: offroadpaint.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/cryptotwerpz.csv
# File Name: cryptotwerpz.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/claypetfox12.csv
# File Name: claypetfox12.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/battlegames1.csv
# File Name: battlegames1.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/kacreations1.csv
# File Name: kacreations1.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/ootygerartoo.csv
# File Name: ootygerartoo.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/bitkenstanxx.csv
# File Name: bitkenstanxx.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/safexnft5555.csv
# File Name: safexnft5555.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/houlehoopshh.csv
# File Name: houlehoopshh.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/stickergamee.csv
# File Name: stickergamee.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/rowdoesstuff.csv
# File Name: rowdoesstuff.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/locationcard.csv
# File Name: locationcard.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/crypticdzign.csv
# File Name: crypticdzign.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/blanesstudio.csv
# File Name: blanesstudio.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/mattaoinesia.csv
# File Name: mattaoinesia.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/manolinhonft.csv
# File Name: manolinhonft.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/animalbreeds.csv
# File Name: animalbreeds.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/cyberporntwo.csv
# File Name: cyberporntwo.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/reauofficial.csv
# File Name: reauofficial.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/backsllkiozx.csv
# File Name: backsllkiozx.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/cbanotshotsx.csv
# File Name: cbanotshotsx.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/sillypsybenx.csv
# File Name: sillypsybenx.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/drawingmss21.csv
# File Name: drawingmss21.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/aprilletters.csv
# File Name: aprilletters.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/cryptocrops1.csv
# File Name: cryptocrops1.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/eosgocards11.csv
# File Name: eosgocards11.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/mundovilnfts.csv
# File Name: mundovilnfts.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/artburnstash.csv
# File Name: artburnstash.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/solarsystem1.csv
# File Name: solarsystem1.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/blueprints11.csv
# File Name: blueprints11.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/worldofgemin.csv
# File Name: worldofgemin.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/freakyfoodzz.csv
# File Name: freakyfoodzz.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/fruitelves12.csv
# File Name: fruitelves12.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/dragonballxx.csv
# File Name: dragonballxx.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/rarezcollect.csv
# File Name: rarezcollect.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/varievarie12.csv
# File Name: varievarie12.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/alienworilds.csv
# File Name: alienworilds.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/samuraigirls.csv
# File Name: samuraigirls.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/pokeyforever.csv
# File Name: pokeyforever.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/elementalpix.csv
# File Name: elementalpix.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/aliienworids.csv
# File Name: aliienworids.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/nftastrology.csv
# File Name: nftastrology.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/ligermanspor.csv
# File Name: ligermanspor.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/ml1libtoopps.csv
# File Name: ml1libtoopps.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/ussrstampsjf.csv
# File Name: ussrstampsjf.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/catfresharts.csv
# File Name: catfresharts.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/amamainart15.csv
# File Name: amamainart15.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/crazyequines.csv
# File Name: crazyequines.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/mosaicstamps.csv
# File Name: mosaicstamps.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/mlbtoppsball.csv
# File Name: mlbtoppsball.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/natalysketch.csv
# File Name: natalysketch.csv
# Content:
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/cyberbullyin.csv
# File Name: cyberbullyin.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/cc32dninenft.csv
# File Name: cc32dninenft.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/upland.cards.csv
# File Name: upland.cards.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/cryptonormyz.csv
# File Name: cryptonormyz.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/orbitofsolus.csv
# File Name: orbitofsolus.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/cryptenthuss.csv
# File Name: cryptenthuss.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/bestwishes4u.csv
# File Name: bestwishes4u.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/catartnfts21.csv
# File Name: catartnfts21.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/tribe.ladz.csv
# File Name: tribe.ladz.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/skullwithin1.csv
# File Name: skullwithin1.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/luketonftart.csv
# File Name: luketonftart.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/wax.comics.csv
# File Name: wax.comics.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/mlllbttoopps.csv
# File Name: mlllbttoopps.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/theshapesnft.csv
# File Name: theshapesnft.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/twerkyypepes.csv
# File Name: twerkyypepes.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/gyratinghips.csv
# File Name: gyratinghips.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/waxartcards1.csv
# File Name: waxartcards1.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/travnastyart.csv
# File Name: travnastyart.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/bosqueclanv1.csv
# File Name: bosqueclanv1.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/freshydroppy.csv
# File Name: freshydroppy.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/allienwulrds.csv
# File Name: allienwulrds.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/splintrlands.csv
# File Name: splintrlands.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/2cryptokingg.csv
# File Name: 2cryptokingg.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/alllianworld.csv
# File Name: alllianworld.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/alienlworlds.csv
# File Name: alienlworlds.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/standardpack.csv
# File Name: standardpack.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/angryflygame.csv
# File Name: angryflygame.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/nfttraveling.csv
# File Name: nfttraveling.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/paintingart3.csv
# File Name: paintingart3.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/craslhgordon.csv
# File Name: craslhgordon.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/myrenderhead.csv
# File Name: myrenderhead.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/tribalbooks.csv
# File Name: tribalbooks.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/rplanetpacks.csv
# File Name: rplanetpacks.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/ultrehorrors.csv
# File Name: ultrehorrors.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/alleniworlds.csv
# File Name: alleniworlds.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/itsthegoiter.csv
# File Name: itsthegoiter.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/coinbots1111.csv
# File Name: coinbots1111.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/1coolartnft1.csv
# File Name: 1coolartnft1.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/baddingtons1.csv
# File Name: baddingtons1.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/realoriginal.csv
# File Name: realoriginal.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/eosnationama.csv
# File Name: eosnationama.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/aiiencworlds.csv
# File Name: aiiencworlds.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/demodemodemo.csv
# File Name: demodemodemo.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/goldmannstax.csv
# File Name: goldmannstax.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/jamtinwaxart.csv
# File Name: jamtinwaxart.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/spinningicon.csv
# File Name: spinningicon.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/kaosmoonibc1.csv
# File Name: kaosmoonibc1.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/olditemworld.csv
# File Name: olditemworld.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/alienfworlds.csv
# File Name: alienfworlds.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/fondmemories.csv
# File Name: fondmemories.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/boid4science.csv
# File Name: boid4science.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/a1ienvvor1de.csv
# File Name: a1ienvvor1de.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/1pokemenbolg.csv
# File Name: 1pokemenbolg.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/eacollection.csv
# File Name: eacollection.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/tstrialsnfts.csv
# File Name: tstrialsnfts.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/rubioriginal.csv
# File Name: rubioriginal.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/dogpatchbrew.csv
# File Name: dogpatchbrew.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/pixellabs123.csv
# File Name: pixellabs123.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/mlbbtoppsver.csv
# File Name: mlbbtoppsver.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/waxnftstamps.csv
# File Name: waxnftstamps.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/madshadowart.csv
# File Name: madshadowart.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/mlbtoppsveri.csv
# File Name: mlbtoppsveri.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/soundzonenft.csv
# File Name: soundzonenft.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/cutiewaifu4u.csv
# File Name: cutiewaifu4u.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/cryptodrugsy.csv
# File Name: cryptodrugsy.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/mycryptocaps.csv
# File Name: mycryptocaps.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/gemsfrmnaron.csv
# File Name: gemsfrmnaron.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/misfitspland.csv
# File Name: misfitspland.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/aliensworlds.csv
# File Name: aliensworlds.csv
# Content:
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/lastdaysfiat.csv
# File Name: lastdaysfiat.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/upliftart.csv
# File Name: upliftart.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/comicsdcntrl.csv
# File Name: comicsdcntrl.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/itsartinarts.csv
# File Name: itsartinarts.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/aiienvvorlds.csv
# File Name: aiienvvorlds.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/allenvvorlds.csv
# File Name: allenvvorlds.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/kernelillokp.csv
# File Name: kernelillokp.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/zerotwozeroz.csv
# File Name: zerotwozeroz.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/zanygumballs.csv
# File Name: zanygumballs.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/catcartegwel.csv
# File Name: catcartegwel.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/tokenhead.csv
# File Name: tokenhead.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/fwdcollction.csv
# File Name: fwdcollction.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/crptoskillrs.csv
# File Name: crptoskillrs.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/mugzbyjwdnft.csv
# File Name: mugzbyjwdnft.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/savantcollec.csv
# File Name: savantcollec.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/hurtinniftys.csv
# File Name: hurtinniftys.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/aigeometrics.csv
# File Name: aigeometrics.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/pokemoncardd.csv
# File Name: pokemoncardd.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/alienanomaly.csv
# File Name: alienanomaly.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/ailllenworld.csv
# File Name: ailllenworld.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/digitalpetzz.csv
# File Name: digitalpetzz.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/reuploaddeut.csv
# File Name: reuploaddeut.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/cryptostars1.csv
# File Name: cryptostars1.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/a1ienvvorlds.csv
# File Name: a1ienvvorlds.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/allennworlds.csv
# File Name: allennworlds.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/digipiglets1.csv
# File Name: digipiglets1.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/dnabloodwrld.csv
# File Name: dnabloodwrld.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/niftycloud33.csv
# File Name: niftycloud33.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/japanstamp22.csv
# File Name: japanstamp22.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/alienswor1ds.csv
# File Name: alienswor1ds.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/alienwoorild.csv
# File Name: alienwoorild.csv
# Content:
#
# ...
# File Name: mundobitcoin.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/doodlenoodle.csv
# File Name: doodlenoodle.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/organicpics1.csv
# File Name: organicpics1.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/cryptopuzzle.csv
# File Name: cryptopuzzle.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/hashkingsmuv.csv
# File Name: hashkingsmuv.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/mfjglassssss.csv
# File Name: mfjglassssss.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/octopusmm111.csv
# File Name: octopusmm111.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/lbarintexasl.csv
# File Name: lbarintexasl.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/fallingupnft.csv
# File Name: fallingupnft.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/beautyofntr1.csv
# File Name: beautyofntr1.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/skullartlife.csv
# File Name: skullartlife.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/despairlovez.csv
# File Name: despairlovez.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/kryptccrypto.csv
# File Name: kryptccrypto.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/volcanoaesop.csv
# File Name: volcanoaesop.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/thepomodoros.csv
# File Name: thepomodoros.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/emilnazaroff.csv
# File Name: emilnazaroff.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/alienwvorlds.csv
# File Name: alienwvorlds.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/ccdmacrolife.csv
# File Name: ccdmacrolife.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/pictureofart.csv
# File Name: pictureofart.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/weed4pothead.csv
# File Name: weed4pothead.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/theonlykarma.csv
# File Name: theonlykarma.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/fatjimmyamps.csv
# File Name: fatjimmyamps.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/redplanetart.csv
# File Name: redplanetart.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/magnta555art.csv
# File Name: magnta555art.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/theartisyart.csv
# File Name: theartisyart.csv
# Content:
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/niftysticker.csv
# File Name: niftysticker.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/dogemoncards.csv
# File Name: dogemoncards.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/smartowl1123.csv
# File Name: smartowl1123.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/risingstarga.csv
# File Name: risingstarga.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/artcryptogif.csv
# File Name: artcryptogif.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/coindodocard.csv
# File Name: coindodocard.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/meditationft.csv
# File Name: meditationft.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/marcosdkarte.csv
# File Name: marcosdkarte.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/bitcoinelite.csv
# File Name: bitcoinelite.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/buterusart13.csv
# File Name: buterusart13.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/mlllbtooppss.csv
# File Name: mlllbtooppss.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/cardbardgame.csv
# File Name: cardbardgame.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/myzombiecats.csv
# File Name: myzombiecats.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/lylpaintings.csv
# File Name: lylpaintings.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/ambidextrous.csv
# File Name: ambidextrous.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/pepe.csv
# File Name: pepe.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/earth2cardss.csv
# File Name: earth2cardss.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/kylverprogzz.csv
# File Name: kylverprogzz.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/theflatlines.csv
# File Name: theflatlines.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/warclanstime.csv
# File Name: warclanstime.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/nerdherd1111.csv
# File Name: nerdherd1111.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/litetigertes.csv
# File Name: litetigertes.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/kingsburynft.csv
# File Name: kingsburynft.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/alienoworlds.csv
# File Name: alienoworlds.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/legendary111.csv
# File Name: legendary111.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/creationblok.csv
# File Name: creationblok.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/alienworldio.csv
# File Name: alienworldio.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/virtualakart.csv
# File Name: virtualakart.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/mllbtoppsver.csv
# File Name: mllbtoppsver.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/evogamingart.csv
# File Name: evogamingart.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/enterseries1.csv
# File Name: enterseries1.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/zombaeseries.csv
# File Name: zombaeseries.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/sacredcircle.csv
# File Name: sacredcircle.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/iminedphuktu.csv
# File Name: iminedphuktu.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/alieenworlld.csv
# File Name: alieenworlld.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/rplanetverif.csv
# File Name: rplanetverif.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/dogecoinkidd.csv
# File Name: dogecoinkidd.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/ml1btoppeese.csv
# File Name: ml1btoppeese.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/divinftyser1.csv
# File Name: divinftyser1.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/periodictabl.csv
# File Name: periodictabl.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/cryptidecard.csv
# File Name: cryptidecard.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/reallifereal.csv
# File Name: reallifereal.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/endlessloots.csv
# File Name: endlessloots.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/rp1anetverif.csv
# File Name: rp1anetverif.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/officialcozy.csv
# File Name: officialcozy.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/lysergicmind.csv
# File Name: lysergicmind.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/graffcologne.csv
# File Name: graffcologne.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/nytcreatures.csv
# File Name: nytcreatures.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/cryptouno1st.csv
# File Name: cryptouno1st.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/cryptoatacks.csv
# File Name: cryptoatacks.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/writer.csv
# File Name: writer.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/gpk.topps.csv
# File Name: gpk.topps.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/cryptocactus.csv
# File Name: cryptocactus.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/justlearnpod.csv
# File Name: justlearnpod.csv
# Content:
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/mutants.r2.csv
# File Name: mutants.r2.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/cryptobadzzz.csv
# File Name: cryptobadzzz.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/joinmyshower.csv
# File Name: joinmyshower.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/aalienworlds.csv
# File Name: aalienworlds.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/nastyhooks4u.csv
# File Name: nastyhooks4u.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/cheesmansart.csv
# File Name: cheesmansart.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/cryptobabes1.csv
# File Name: cryptobabes1.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/pixelheads21.csv
# File Name: pixelheads21.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/mlbbtoppssgg.csv
# File Name: mlbbtoppssgg.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/trippyflowzz.csv
# File Name: trippyflowzz.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/byronszbcats.csv
# File Name: byronszbcats.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/robonomicaio.csv
# File Name: robonomicaio.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/elementblobs.csv
# File Name: elementblobs.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/allensworlbs.csv
# File Name: allensworlbs.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/classicaltat.csv
# File Name: classicaltat.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/nftbulls4141.csv
# File Name: nftbulls4141.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/waxromanians.csv
# File Name: waxromanians.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/soulaniagame.csv
# File Name: soulaniagame.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/mlllbbtoopps.csv
# File Name: mlllbbtoopps.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/theornigod13.csv
# File Name: theornigod13.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/metalwargame.csv
# File Name: metalwargame.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/leftarmover1.csv
# File Name: leftarmover1.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/chssgraphics.csv
# File Name: chssgraphics.csv
# Content:
#
# Location: /Users/jorgeolmos/Documents/capstone/SMU_MSDS_CAPSTONE_2022/Data Slices/5_days_all_metrics/gameskardsmk.csv
# File Name: gameskardsmk.csv
# Content:

# %%
list(my_dict.values())[0]
# Out:
#    Unnamed: 0    index Smart_contract      ID_token  Transaction_hash  \
# 0           0  3039376   atomicassets  1.099522e+12               NaN
# 1           1  3039349   atomicassets  1.099522e+12               NaN
# 2           2  3000630   atomicassets  1.099522e+12               NaN
#
#   Seller_address  Seller_username Buyer_address  Buyer_username  \
# 0      jxpb4.wam              NaN     o5gqy.wam             NaN
# 1      jxpb4.wam              NaN     iykb2.wam             NaN
# 2      jxpb4.wam              NaN     uvmb4.wam             NaN
#
#                                       Image_url_1  ... Permanent_link  \
# 0  QmSsiEynYQaD9pLCH9R3y3WYdxnVtdGiiCE2hjMEFW1iDK  ...            NaN
# 1  QmSsiEynYQaD9pLCH9R3y3WYdxnVtdGiiCE2hjMEFW1iDK  ...            NaN
# 2  QmcVNJpeXeaAa2tRvxFqP9z23LNp5xjKiE3EPE3Dz9ncC1  ...            NaN
#
#                 Unique_id_collection Collection_cleaned  Category   density  \
# 0  ('space1catzzz', '1099521591310')              Space     Other  1.000000
# 1  ('space1catzzz', '1099521591311')              Space     Other  0.666667
# 2  ('space1catzzz', '1099521811858')              Space     Other  0.500000
#
#    vertex_count  edge_count  max_diameter max_radius max_periphery
# 0             2           1             1          1             2
# 1             3           2             2          1             2
# 2             4           3             2          1             3
#
# [3 rows x 32 columns]
