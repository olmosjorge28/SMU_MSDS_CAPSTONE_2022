# %%
# standard libraries
import pandas as pd
import numpy as np
import os
from IPython.display import Image
#from IPython.display import clear_output
import time
import json
#import re

# visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from tabulate import tabulate
import altair as alt
alt.data_transformers.disable_max_rows()
# Out:
# DataTransformerRegistry.enable('default')

# %%
#from community import community_louvain
from networkx.algorithms.community import greedy_modularity_communities
import community
import matplotlib.cm as cm
import matplotlib.pyplot as plt

# %%
from os import listdir
from os.path import isfile, join

class FilePathManager:
    def __init__(self, local_dir: str):
        self.local_dir = local_dir
    
    def retrieve_full_path(self):
        return os.getcwd()+'/'+self.local_dir

# %%
from os import listdir
from os.path import isfile, join

class FilePathManager:
    def __init__(self, local_dir: str):
        self.local_dir = local_dir
    
    def retrieve_full_path(self):
        return os.getcwd()+'\\'+self.local_dir

# %%
class Loader:
    df = pd.DataFrame()
    
    def load_data(self, file_name):
        pass
    
    def get_df(self):
        pass
    
    def size(self):
        return len(self.df)

# %%
from typing import Callable
 
class CSVLoader(Loader):
    def __init__(self, file_path_manager: FilePathManager):
        self.file_path_manager = file_path_manager
        
    def load_data(self, _prepare_data: Callable[[pd.DataFrame], pd.DataFrame] = None):
        self.df = pd.read_csv(self.file_path_manager.retrieve_full_path(), low_memory=False)
        if _prepare_data:
            self.df = _prepare_data(self.df)
    
    def get_df(self):
        return self.df;
    
    def size(self):
        return len(self.df)

# %%
def clean_data(df):
    df['Datetime_updated'] = pd.to_datetime(df['Datetime_updated'], infer_datetime_format=True)
    df['Datetime_updated_seconds'] = pd.to_datetime(df['Datetime_updated_seconds'], infer_datetime_format=True)
    return df

# %%
loader = CSVLoader(FilePathManager('Data_API.csv.gz'))
loader.load_data(clean_data)
df = loader.get_df()

# %%
# get target variable labels
f = open('atomichub.config')
data = json.load(f)
blist = data.get('data').get('global').get('col.blist')
wlist = data.get('data').get('global').get('col.wlist')

# %%
print("# blacklisted collections on AtomicHub:", len(blist))
print("# whitelisted collections on AtomicHub:", len(wlist))
# Out:
# # blacklisted collections on AtomicHub: 5941
# # whitelisted collections on AtomicHub: 2352

# %%
# match target variable labels with collection names in dataset
blacklist = []
whitelist = []
neither = []
for c in gb.groups.keys():
    blacklisted = True if c in blist else False
    whitelisted = True if c in wlist else False
    if blacklisted:
        blacklist.append(1)
    else:
        blacklist.append(0)
    if whitelisted:
        whitelist.append(1)
    else:
        whitelist.append(0)
    if not blacklisted and not whitelisted:
        neither.append(1)
    else:
        neither.append(0)

# %%
coll_labels = pd.DataFrame({'collection':gb.groups.keys(),'blacklist':blacklist, 'whitelist':whitelist, 'neither':neither})
coll_labels
# Out:
#                                       collection  blacklist  whitelist  \
# 0                                      0-domains          0          0
# 1                               0x-meets-imtoken          0          0
# 2     0x001ba7dc2ddfa893c17b6b478c9853b83fc8594c          0          0
# 3                                 0xbitcoinmemes          0          0
# 4                                        0xearth          0          0
# ...                                          ...        ...        ...
# 6278                                zodiacstars1          0          0
# 6279                                zombaeseries          0          1
# 6280                                zombieartist          0          1
# 6281                                zombiesperks          0          0
# 6282                                zweihspacert          0          0
#
#       neither
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# ...       ...
# 6278        1
# 6279        0
# 6280        0
# 6281        1
# 6282        1
#
# [6283 rows x 4 columns]

# %%
print('blacklisted collections in dataset:', sum(coll_labels['blacklist']), ",", 
      round(sum(coll_labels['blacklist'])/coll_labels.shape[0]*100,1),'%')
print('\nwhitelisted collections in dataset:', sum(coll_labels['whitelist']), ",",
      round(sum(coll_labels['whitelist'])/coll_labels.shape[0]*100,1),'%')
print('\ncollections not white or black listed in dataset:', sum(coll_labels['neither']), ",", 
      round(sum(coll_labels['neither'])/coll_labels.shape[0]*100,1),'%')
# Out:
# blacklisted collections in dataset: 275 , 4.4 %
#
# whitelisted collections in dataset: 720 , 11.5 %
#
# collections not white or black listed in dataset: 5288 , 84.2 %

# %%
# Collections for model training 
coll_train = coll_labels[coll_labels['neither']==0]
coll_train
# Out:
#         collection  blacklist  whitelist  neither
# 31    12345rainbow          1          0        0
# 40    1amazingbook          0          1        0
# 43    1bitcoinlive          0          1        0
# 46    1bodyinmove1          0          1        0
# 50    1coolartnft1          0          1        0
# ...            ...        ...        ...      ...
# 6272  zeugencorona          1          0        0
# 6274  zippergirls1          0          1        0
# 6275  zlfhomedecor          0          1        0
# 6279  zombaeseries          0          1        0
# 6280  zombieartist          0          1        0
#
# [995 rows x 4 columns]

# %%
gb = df.groupby('Collection')

# %%
print( "total # of unique collections in dataset:", len(gb.groups.keys()) )
# Out:
# total # of unique collections in dataset: 6283

# %%
# create a list of dataframes for all collections that are whitelisted or blacklisted
collection_dfs = [(x, gb.get_group(x)) for x in coll_train['collection']]

# %%
print("total # of black/whitelisted collections in dataset:", len(collection_dfs))
# Out:
# total # of black/whitelisted collections in dataset: 995

# %%
collection_dfs[100][1].head()
# Out:
#         Smart_contract      ID_token Transaction_hash Seller_address  \
# 3137139   atomicassets  1.099524e+12              NaN      sg54o.wam
# 3137154   atomicassets  1.099524e+12              NaN      sg54o.wam
# 3137224   atomicassets  1.099524e+12              NaN      sg54o.wam
# 3139677   atomicassets  1.099524e+12              NaN      aw4bi.wam
# 3139774   atomicassets  1.099524e+12              NaN      aw4bi.wam
#
#         Seller_username Buyer_address Buyer_username  \
# 3137139             NaN     enmbe.wam            NaN
# 3137154             NaN     t4mra.wam            NaN
# 3137224             NaN     gd5ri.wam            NaN
# 3139677             NaN     tsqra.wam            NaN
# 3139774             NaN     t4mra.wam            NaN
#
#                                             Image_url_1  \
# 3137139  QmaaYjo6Nq48mZfmy53ZVqcvxZHXWUPjpduAKzQvf3gu27
# 3137154  QmaaYjo6Nq48mZfmy53ZVqcvxZHXWUPjpduAKzQvf3gu27
# 3137224  QmaaYjo6Nq48mZfmy53ZVqcvxZHXWUPjpduAKzQvf3gu27
# 3139677  QmaaYjo6Nq48mZfmy53ZVqcvxZHXWUPjpduAKzQvf3gu27
# 3139774  QmaaYjo6Nq48mZfmy53ZVqcvxZHXWUPjpduAKzQvf3gu27
#
#                                                Image_url_2  \
# 3137139  https://ipfs.io/ipfs/QmaaYjo6Nq48mZfmy53ZVqcvx...
# 3137154  https://ipfs.io/ipfs/QmaaYjo6Nq48mZfmy53ZVqcvx...
# 3137224  https://ipfs.io/ipfs/QmaaYjo6Nq48mZfmy53ZVqcvx...
# 3139677  https://ipfs.io/ipfs/QmaaYjo6Nq48mZfmy53ZVqcvx...
# 3139774  https://ipfs.io/ipfs/QmaaYjo6Nq48mZfmy53ZVqcvx...
#
#                                                Image_url_3  ... Name  \
# 3137139  https://ipfs.atomichub.io/ipfs/QmaaYjo6Nq48mZf...  ...  NaN
# 3137154  https://ipfs.atomichub.io/ipfs/QmaaYjo6Nq48mZf...  ...  NaN
# 3137224  https://ipfs.atomichub.io/ipfs/QmaaYjo6Nq48mZf...  ...  NaN
# 3139677  https://ipfs.atomichub.io/ipfs/QmaaYjo6Nq48mZf...  ...  NaN
# 3139774  https://ipfs.atomichub.io/ipfs/QmaaYjo6Nq48mZf...  ...  NaN
#
#          Description    Collection  Market Datetime_updated  \
# 3137139          NaN  allenvvorlds  Atomic       2021-04-14
# 3137154          NaN  allenvvorlds  Atomic       2021-04-14
# 3137224          NaN  allenvvorlds  Atomic       2021-04-14
# 3139677          NaN  allenvvorlds  Atomic       2021-04-14
# 3139774          NaN  allenvvorlds  Atomic       2021-04-14
#
#         Datetime_updated_seconds Permanent_link  \
# 3137139      2021-04-14 22:03:14            NaN
# 3137154      2021-04-14 22:02:58            NaN
# 3137224      2021-04-14 22:01:42            NaN
# 3139677      2021-04-14 21:07:15            NaN
# 3139774      2021-04-14 21:04:15            NaN
#
#                       Unique_id_collection Collection_cleaned Category
# 3137139  ('allenvvorlds', '1099523870996')                All    Other
# 3137154  ('allenvvorlds', '1099523870997')                All    Other
# 3137224  ('allenvvorlds', '1099523870998')                All    Other
# 3139677  ('allenvvorlds', '1099523870989')                All    Other
# 3139774  ('allenvvorlds', '1099523870993')                All    Other
#
# [5 rows x 24 columns]

# %%
collection_dfs[100][1][['Datetime_updated_seconds','Price_USD', 'Price_Crypto']]
# Out:
#         Datetime_updated_seconds  Price_USD  Price_Crypto
# 3137139      2021-04-14 22:03:14   5.805600     24.000000
# 3137154      2021-04-14 22:02:58   5.805600     24.000000
# 3137224      2021-04-14 22:01:42   5.805600     24.000000
# 3139677      2021-04-14 21:07:15   6.289400     26.000000
# 3139774      2021-04-14 21:04:15   5.805600     24.000000
# 3139941      2021-04-14 20:59:59   5.805600     24.000000
# 3139977      2021-04-14 20:59:04   5.805600     24.000000
# 3140033      2021-04-14 20:58:04   5.805600     24.000000
# 3140069      2021-04-14 20:57:09   5.805600     24.000000
# 3141036      2021-04-14 20:35:32   6.047500     25.000000
# 3141094      2021-04-14 20:35:01   6.047500     25.000000
# 3141619      2021-04-14 20:28:12   6.047500     25.000000
# 3141680      2021-04-14 20:26:47   6.047500     25.000000
# 3141850      2021-04-14 20:22:25   7.120690     29.436501
# 3141860      2021-04-14 20:22:13   7.141712     29.523408
# 3142915      2021-04-14 19:55:06   5.805600     24.000000
# 3143905      2021-04-14 19:32:49   6.047500     25.000000
# 3144536      2021-04-14 19:17:50   6.289400     26.000000
# 3144566      2021-04-14 19:16:56   6.289400     26.000000
# 3144634      2021-04-14 19:15:30   6.531300     27.000000
# 3144681      2021-04-14 19:14:22   6.773200     28.000000
# 3144709      2021-04-14 19:13:26   6.773200     28.000000
# 3144771      2021-04-14 19:11:51   7.257000     30.000000
# 3144929      2021-04-14 19:08:27   7.257000     30.000000
# 3144978      2021-04-14 19:07:22   6.773200     28.000000
# 3145064      2021-04-14 19:05:41   6.773200     28.000000
# 3146519      2021-04-14 18:26:13   6.047500     25.000000
# 3148104      2021-04-14 17:41:42   6.531300     27.000000
# 3149218      2021-04-14 17:11:40   6.047500     25.000000
# 3149263      2021-04-14 17:10:11   6.531300     27.000000
# 3149391      2021-04-14 17:06:12   7.015100     29.000000
# 3149417      2021-04-14 17:05:15   7.257000     30.000000
# 3149430      2021-04-14 17:04:44   7.015100     29.000000
# 3149782      2021-04-14 16:56:04   7.015100     29.000000
# 3149989      2021-04-14 16:51:39   6.531300     27.000000
# 3150827      2021-04-14 16:25:42   6.880574     28.443878
# 3151610      2021-04-14 16:06:15   7.015100     29.000000
# 3151870      2021-04-14 15:58:45   7.257000     30.000000
# 3151904      2021-04-14 15:57:43   7.015100     29.000000
# 3151945      2021-04-14 15:56:27   7.015100     29.000000
# 3151989      2021-04-14 15:54:57   7.015100     29.000000
# 3152063      2021-04-14 15:53:18   7.257000     30.000000
# 3152109      2021-04-14 15:52:04   7.015100     29.000000
# 3152141      2021-04-14 15:50:57   7.257000     30.000000
# 3152146      2021-04-14 15:50:39   6.265210     25.900000
# 3152198      2021-04-14 15:48:05   7.257000     30.000000
# 3153178      2021-04-14 15:15:30   7.015100     29.000000
# 3153212      2021-04-14 15:14:37   6.773200     28.000000
# 3153227      2021-04-14 15:14:03   7.015100     29.000000
# 3153397      2021-04-14 15:09:45   8.466500     35.000000
# 3153671      2021-04-14 15:00:23   6.773200     28.000000
# 3153696      2021-04-14 14:59:37   7.257000     30.000000
# 3153709      2021-04-14 14:59:04   7.257000     30.000000
# 3153724      2021-04-14 14:58:23   7.257000     30.000000
# 3153883      2021-04-14 14:51:10   7.257000     30.000000

# %%
sns.lineplot()

# %%
def convert_to_ts(collection, time_range):
    ts_collection = collection.reset_index(drop=True)
    ts_collection.loc[ts_collection[['Datetime_updated_seconds']].duplicated(),'Datetime_updated_seconds']= \
    ts_collection[ts_collection[['Datetime_updated_seconds']].duplicated()]['Datetime_updated_seconds'].\
    map(lambda x: x + pd.to_timedelta(1, unit='s'), na_action=None)
    
    volume = ts_collection[['Datetime_updated_seconds','Price_USD','Price_Crypto']].\
    set_index('Datetime_updated_seconds').resample(time_range).agg({"Price_USD":'size'})
    
    ts_collection = ts_collection[['Datetime_updated_seconds','Price_USD','Price_Crypto']].\
    set_index('Datetime_updated_seconds').resample(time_range).mean().ffill()
    ts_collection['volume'] = volume['Price_USD']
    return ts_collection

# %%
timeseries = []

full_dataset = None
for collection in collection_dfs:
    name = str(collection[0])
    collection_values = col_train.loc[col_train['collection']==name][['blacklist', 'whitelist']].values
    a_ts_collection = None
    if collection_values[0][0] == 1:
        a_ts_collection = convert_to_ts(collection[1], '1d')
        a_ts_collection['collection'] = name
        a_ts_collection['blacklisted'] = '1'
        a_ts_collection['whitelisted'] = '0'
    if collection_values[0][1] == 1:
        a_ts_collection = convert_to_ts(collection[1], '1d')
        a_ts_collection['collection'] = name
        a_ts_collection['blacklisted'] = '0'
        a_ts_collection['whitelisted'] = '1'

    if a_ts_collection is not None:
        if full_dataset is not None:
            full_dataset = pd.concat([full_dataset, a_ts_collection])
        else:
            full_dataset = a_ts_collection

# %%
full_dataset.head()
# Out:
#                           Price_USD  Price_Crypto  volume    collection  \
# Datetime_updated_seconds
# 2020-12-02                 0.040150        1.0000       1  12345rainbow
# 2020-12-03                 0.040150        1.0000       0  12345rainbow
# 2020-12-04                 0.036259        0.9900       1  12345rainbow
# 2021-03-31                 0.131440        0.5025       2  1amazingbook
# 2021-04-01                 0.261350        1.0000       1  1amazingbook
#
#                          blacklisted whitelisted
# Datetime_updated_seconds
# 2020-12-02                         1           0
# 2020-12-03                         1           0
# 2020-12-04                         1           0
# 2021-03-31                         0           1
# 2021-04-01                         0           1

# %%
trading_days = pd.DataFrame(full_dataset['collection'].value_counts())
trading_days.columns = ['days']
trading_days
# Out:
#               days
# anyo.b1        302
# niftywizards   300
# badges.b1      299
# dopestickers   299
# pepe.hero      298
# ...            ...
# beautywifeee     1
# leftarmover1     1
# lastdaysfiat     1
# aliensworldc     1
# mlllbtooppss     1
#
# [995 rows x 1 columns]

# %%
# Proportion of white/blacklisted collections
trading_days.value_counts(normalize=True)
# Out:
# days
# 1       0.235176
# 2       0.052261
# 3       0.038191
# 4       0.022111
# 11      0.018090
#           ...
# 150     0.001005
# 148     0.001005
# 146     0.001005
# 145     0.001005
# 302     0.001005
# Length: 187, dtype: float64

# %%
one_day_idx = trading_days[trading_days['days']==1].index

# %%
one_day_coll = full_dataset.loc[full_dataset['collection'].isin(one_day_idx)]
one_day_coll
# Out:
#                           Price_USD  Price_Crypto  volume    collection  \
# Datetime_updated_seconds
# 2021-01-29                 0.838200     20.000000       1  1pokemenbolg
# 2021-04-06                 0.242300      1.000000       1  3doddities33
# 2021-03-29                26.650000    100.000000       4  515toysinthe
# 2021-04-15                 3.672956     15.037692      26  a11ianworlds
# 2021-04-14                 3.345426     13.829787      47  a1ieneworlds
# ...                             ...           ...     ...           ...
# 2021-03-12                 2.346000     10.000000       1  wickedsketch
# 2020-10-17                 0.038345      1.000000       1  xnxxdotcom11
# 2021-04-09                 1.159250      5.000000       1  xthingscards
# 2021-03-27                 2.361487      9.501812       4  yetigraffiti
# 2021-01-08                 7.169295    162.366539      26  zamuraionwax
#
#                          blacklisted whitelisted
# Datetime_updated_seconds
# 2021-01-29                         1           0
# 2021-04-06                         0           1
# 2021-03-29                         0           1
# 2021-04-15                         1           0
# 2021-04-14                         1           0
# ...                              ...         ...
# 2021-03-12                         1           0
# 2020-10-17                         1           0
# 2021-04-09                         0           1
# 2021-03-27                         0           1
# 2021-01-08                         1           0
#
# [234 rows x 6 columns]

# %%
sum_one_day_blist = one_day_coll['blacklisted'].astype(int).sum()
sum_all_blist = sum(coll_labels['blacklist'])
print("# blacklisted collections with only 1 day of trades:", sum_one_day_blist)
print("% of all blacklisted collections with only 1 day of trades:", round(sum_one_day_blist/sum_all_blist*100,1),'%')

sum_one_day_wlist = one_day_coll['whitelisted'].astype(int).sum()
sum_all_wlist = sum(coll_labels['whitelist'])
print("\n# whitelisted collections with only 1 day of trades:", sum_one_day_wlist)
print("% of all whitelisted collections with only 1 day of trades:", round(sum_one_day_wlist/sum_all_wlist*100,1),'%')
# Out:
# # blacklisted collections with only 1 day of trades: 141
# % of all blacklisted collections with only 1 day of trades: 51.3 %
#
# # whitelisted collections with only 1 day of trades: 93
# % of all whitelisted collections with only 1 day of trades: 12.9 %

# %%
# many of these are fraudulent due to knock-off collections names
np.array(one_day_coll[one_day_coll['blacklisted']=='1']['collection'])
# Out:
# array(['1pokemenbolg', 'a11ianworlds', 'a1ieneworlds', 'a1ienlwor1ds',
#        'a1ienoworlds', 'a1ienswor1ds', 'a1ienvvor1de', 'a1ienvvordds',
#        'a1ienvvorlds', 'a1ienzworlds', 'aalienworlds', 'aallienworld',
#        'aiiencworlds', 'aiienvvorlds', 'aiienworldss', 'aillenworlds',
#        'ailllenworld', 'al1ienworl1d', 'ali1enworild', 'alieenworlds',
#        'alieenworlld', 'aliemmworlds', 'aliemswworld', 'alieneworlds',
#        'alienfworlds', 'aliengworlds', 'alienlworlds', 'aliennwiorld',
#        'alienpaworld', 'aliensvvorld', 'alienswor1ds', 'aliensworldc',
#        'aliensworlds', 'alienswworld', 'alienvvor1ds', 'alienvvorld2',
#        'alienvvorlds', 'alienvvworld', 'alienwords23', 'alienworilds',
#        'alienworldio', 'alienworrlds', 'alienwvorlds', 'alienwvvorld',
#        'alienwworlld', 'alienxworlds', 'aliienworids', 'alleenworlds',
#        'alleniworlds', 'allensworlbs', 'allenvvorlds', 'allienwulrds',
#        'allienwurlds', 'alllenworlks', 'alllianworld', 'alonworldscs',
#        'artepileptic', 'beautywifeee', 'bitversevere', 'bitverseveri',
#        'blackmoney12', 'boysofsummur', 'cardseriess1', 'cartoombsir2',
#        'coolasset123', 'craslhgordon', 'creaturanary', 'cryptamoonie',
#        'cryptohentai', 'dogemoncards', 'dungeonworld', 'emilnazaroff',
#        'epilepticimg', 'exit1imbowax', 'exitlimbowam', 'fatboycrypto',
#        'fillthespace', 'flegandsnfts', 'fuzzykitten1', 'gameskardsmk',
#        'gamesofaline', 'holoddgoddgg', 'iramadhanart', 'itsartinarts',
#        'joinmyshower', 'matuntssr2ve', 'mbllltooppps', 'ml1btoppeese',
#        'ml1libtoopps', 'mlbbtoppssgg', 'mlbbtoppsver', 'mlbstoppsver',
#        'mlbtoopppsss', 'mlbtooppsver', 'mlbtopppsver', 'mlbtoppsball',
#        'mlbtoppsveri', 'mlbtoppsverl', 'mlbtopspsver', 'mlbttopllles',
#        'mlbttoppsver', 'mlbxtoppsver', 'mllbtoppsver', 'mllibtooppss',
#        'mlllbbtoopps', 'mlllbtooppss', 'mlllbttoopps', 'mmlbtoppsver',
#        'monalisanft1', 'mrtreefanart', 'mutantsssr2g', 'muttanttssr2',
#        'nerdherd1111', 'officialax11', 'pepelovesall', 'placeitsupzc',
#        'pokemoncardd', 'rplanatverif', 'rplaneeettgg', 'rplanetpacks',
#        'rplanettpack', 'rplanetverif', 'shatnertweet', 'simagigit453',
#        'skyseries123', 'steampunk121', 'surfkoattnft', 'testcollecr4',
#        'thisisatest1', 'ultrahorrore', 'ultrahorrorr', 'ultrahorross',
#        'ultrehorrors', 'upland1cards', 'uplandcardss', 'uplandscards',
#        'varievarie12', 'waxforerotic', 'wickedsketch', 'xnxxdotcom11',
#        'zamuraionwax'], dtype=object)

# %%
# Trade counts (volume) of collections with only 1 day of data
one_day_coll['volume'].value_counts()
# Out:
# 1       107
# 2        34
# 3        21
# 4        18
# 5         8
# 7         6
# 12        4
# 11        4
# 10        4
# 8         4
# 6         3
# 16        2
# 9         2
# 26        2
# 25        2
# 17        2
# 61        1
# 31        1
# 14        1
# 46        1
# 56        1
# 24        1
# 21        1
# 55        1
# 47        1
# 20        1
# 3354      1
# Name: volume, dtype: int64

# %%
one_day_coll[one_day_coll['volume']==3354]
# Out:
#                           Price_USD  Price_Crypto  volume collection  \
# Datetime_updated_seconds
# 2021-04-27                 3.174432     16.626586    3354     weezer
#
#                          blacklisted whitelisted
# Datetime_updated_seconds
# 2021-04-27                         0           1
